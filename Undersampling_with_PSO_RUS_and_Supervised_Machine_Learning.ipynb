# %% [markdown]
# <a href="https://colab.research.google.com/github/ashamril/optimization/blob/master/Undersampling_with_PSO_RUS_and_Supervised_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparison between Imbalanced Dataset vs Undersampling/balancing using **Particle Swarm Optimization (PSO)** vs **Random Undersampling (RUS)**
# # Classification using **Supervised Machine Learning**: ANN, SVM, XGBoost, RF and LR [MLPClassifier(), SVC(), XGBClassifier(), RandomForestClassifier() and LogisticRegression()]

# %%
from datetime import datetime 
from pytz import timezone  
from random import randint
from scipy import spatial
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import f1_score, average_precision_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost.sklearn import XGBClassifier
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import scipy.spatial
import seaborn as sns
import time
import warnings

# %%
# CATEGORICAL = "NO"
# dataset_set = "abalone19"
# program_name = "PSO"
# !wget -O dataset.csv https://raw.githubusercontent.com/ashamril/CSV/master/abalone19.csv

# malaysia = timezone('Asia/Kuala_Lumpur')
# mytime = datetime.now(malaysia)
# first_start_time = datetime.now() 
# start_time = datetime.now() 
# file_path = "/content/dataset.csv"                     
# df = pd.read_csv(file_path, header=0)
# print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))

# df.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight','Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Class']
# df['New_Sex'] = df['Sex'].map(dict(zip(['M','F','I'],[0,1,2])))
# df = df.drop('Sex', axis = 1)
# df['New_Class'] = df['Class'].map(dict(zip([' negative',' positive'],[0,1])))
# df = df.drop('Class', axis = 1)
# df

# %%
# CATEGORICAL = "NO"
# dataset_set = "pima"
# program_name = "PSO"
# !wget -O dataset.csv https://raw.githubusercontent.com/ashamril/CSV/master/pima.csv

# malaysia = timezone('Asia/Kuala_Lumpur')
# mytime = datetime.now(malaysia)
# first_start_time = datetime.now() 
# start_time = datetime.now() 
# file_path = "/content/dataset.csv"                     
# df = pd.read_csv(file_path, header=0)
# print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))

# df['New_Class'] = df['Class'].map(dict(zip(['negative','positive'],[0,1])))
# df = df.drop('Class', axis = 1)
# df

# %%
CATEGORICAL = "YES"
dataset_set = "BankMarketing"
program_name = "PSO"
#!wget -O dataset.csv https://raw.githubusercontent.com/ashamril/CSV/master/bank.csv
# !wget -O dataset.csv https://raw.githubusercontent.com/ashamril/CSV/master/bank-full.csv

malaysia = timezone('Asia/Kuala_Lumpur')
mytime = datetime.now(malaysia)
first_start_time = datetime.now() 
start_time = datetime.now() 
file_path = "/content/dataset.csv"                     
df = pd.read_csv(file_path, sep=';', header=0)
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))

df['New_Class'] = df['y'].map(dict(zip(['no','yes'],[0,1])))
df = df.drop('y', axis = 1)
df
# Out:
# --2020-08-02 18:18:44--  https://raw.githubusercontent.com/ashamril/CSV/master/bank-full.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4610348 (4.4M) [text/plain]
# Saving to: ‘dataset.csv’
#
# dataset.csv         100%[===================>]   4.40M  13.1MB/s    in 0.3s
#
# 2020-08-02 18:18:44 (13.1 MB/s) - ‘dataset.csv’ saved [4610348/4610348]
#
# Time elapsed (hh:mm:ss.ms) 0:00:00.099377
#        age           job   marital  education default  balance housing loan    contact  day month  duration  campaign  pdays  previous poutcome  New_Class
# 0       58    management   married   tertiary      no     2143     yes   no    unknown    5   may       261         1     -1         0  unknown          0
# 1       44    technician    single  secondary      no       29     yes   no    unknown    5   may       151         1     -1         0  unknown          0
# 2       33  entrepreneur   married  secondary      no        2     yes  yes    unknown    5   may        76         1     -1         0  unknown          0
# 3       47   blue-collar   married    unknown      no     1506     yes   no    unknown    5   may        92         1     -1         0  unknown          0
# 4       33       unknown    single    unknown      no        1      no   no    unknown    5   may       198         1     -1         0  unknown          0
# ...    ...           ...       ...        ...     ...      ...     ...  ...        ...  ...   ...       ...       ...    ...       ...      ...        ...
# 45206   51    technician   married   tertiary      no      825      no   no   cellular   17   nov       977         3     -1         0  unknown          1
# 45207   71       retired  divorced    primary      no     1729      no   no   cellular   17   nov       456         2     -1         0  unknown          1
# 45208   72       retired   married  secondary      no     5715      no   no   cellular   17   nov      1127         5    184         3  success          1
# 45209   57   blue-collar   married  secondary      no      668      no   no  telephone   17   nov       508         4     -1         0  unknown          0
# 45210   37  entrepreneur   married  secondary      no     2971      no   no   cellular   17   nov       361         2    188        11    other          0
#
# [45211 rows x 17 columns]

# %%
  plt.figure(figsize=(20,9))
  s = df.New_Class
  counts = s.value_counts().sort_index()
  percent100 = s.value_counts(normalize=True).mul(100).round(2).astype(str) + '%'
  df2 = pd.DataFrame({'Counts': counts, 'Percentage': percent100}).sort_index(ascending=False)
  print(df2)
  print("")
  colors=['green', 'red']
  explode = (0.01, 0)
  df2.Counts.plot(kind='pie', explode=explode, colors=colors, autopct='%1.2f%%', shadow=True, startangle=50, fontsize=15)
  plt.title("Class Distribution [(0/Negative/No) vs (1/Positive/Yes)]. Dataset = {}".format(dataset_set), fontweight='bold', fontsize=15, bbox={'facecolor':'0.8', 'pad':5})
  plt.ylabel('')
  plt.show()
# Out:
#    Counts Percentage
# 1    5289      11.7%
# 0   39922      88.3%

# %%
# Convert categorical data into numerical

if (CATEGORICAL == "YES"):
  from sklearn.preprocessing import LabelEncoder
  df = df.apply(LabelEncoder().fit_transform)
  
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  day  month  duration  campaign  pdays  previous  poutcome  New_Class
# 0       40    4        1          2        0     3036        1     0        2    4      8       261         0      0         0         3          0
# 1       26    9        2          1        0      945        1     0        2    4      8       151         0      0         0         3          0
# 2       15    2        1          1        0      918        1     1        2    4      8        76         0      0         0         3          0
# 3       29    1        1          3        0     2420        1     0        2    4      8        92         0      0         0         3          0
# 4       15   11        2          3        0      917        0     0        2    4      8       198         0      0         0         3          0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...  ...    ...       ...       ...    ...       ...       ...        ...
# 45206   33    9        1          2        0     1741        0     0        0   16      9       975         2      0         0         3          1
# 45207   53    5        0          0        0     2639        0     0        0   16      9       456         1      0         0         3          1
# 45208   54    5        1          1        0     5455        0     0        0   16      9      1116         4    181         3         2          1
# 45209   39    1        1          1        0     1584        0     0        1   16      9       508         3      0         0         3          0
# 45210   19    2        1          1        0     3779        0     0        0   16      9       361         1    185        11         1          0
#
# [45211 rows x 17 columns]

# %% [markdown]
# # Imbalanced Dataset

# %%
# Separating the dependent and independent variables 

test_size = 0.2

X = df.drop('New_Class', axis = 1) 
y = df['New_Class'] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)

# %%
# Plotting the sets

plot_height = (len(df[df.New_Class == 0]) * 0.8) + 100

fig, ax = plt.subplots(1, 2, figsize=(30, 10))
plt.subplot(1, 2, 1)
colors = ["green", "red"]
df_train = pd.DataFrame(y_train.value_counts())
ax = sns.countplot(y_train, data=df_train, palette=colors)
ax.set_ylim(0, plot_height)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
plt.xlabel('Class', fontweight='bold', fontsize=15)
plt.ylabel('Count', fontweight='bold', fontsize=15)
plt.title('TRAIN SET: Class Distributions (0/Negative/No || 1/Positive/Yes)', fontweight='bold', fontsize=15)

plt.subplot(1, 2, 2)
colors = ["green", "red"]
df_train = pd.DataFrame(y_test.value_counts())
ax = sns.countplot(y_test, data=df_train, palette=colors)
ax.set_ylim(0, plot_height)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
plt.xlabel('Class', fontweight='bold', fontsize=15)
plt.ylabel('Count', fontweight='bold', fontsize=15)
plt.title('TEST SET: Class Distributions (0/Negative/No || 1/Positive/Yes)', fontweight='bold', fontsize=15)

print("Imbalanced :")
print("X_train:")
print('Negative', round(y_train.value_counts()[0]/len(y_train) * 100,2), '% of the dataset:', y_train.value_counts()[0])
print('Positive', round(y_train.value_counts()[1]/len(y_train) * 100,2), '% of the dataset:', y_train.value_counts()[1])
print("")
print("X_test:")
print('Negative', round(y_test.value_counts()[0]/len(y_test) * 100,2), '% of the dataset:', y_test.value_counts()[0])
print('Positive', round(y_test.value_counts()[1]/len(y_test) * 100,2), '% of the dataset:', y_test.value_counts()[1])
print("")

plt.show()
# Out:
# Imbalanced :
# X_train:
# Negative 88.28 % of the dataset: 31929
# Positive 11.72 % of the dataset: 4239
#
# X_test:
# Negative 88.39 % of the dataset: 7993
# Positive 11.61 % of the dataset: 1050

# %%
# Classification with Imbalanced Dataset

classifiers = [MLPClassifier(), SVC(probability=True), XGBClassifier(), RandomForestClassifier(), LogisticRegression(max_iter=5000)]
imbalanced_result_table_test = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])
imbalanced_result_table_test_f1 = pd.DataFrame(columns=['Classifiers', 'Accuracy','Sensitivity', 'Specificity', 'Precision', 'F1Score', 'AUC', 'AveragePrecisionRecall'])

for cls in classifiers:
    model = cls.fit(X_train, y_train)

    # TEST set
    yproba = model.predict_proba(X_test)[::,1]
    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)
    imbalanced_result_table_test = imbalanced_result_table_test.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)
    
    print("=====================================================================")
    print("Classifier = ", cls)
    print("TEST SET")
    y_pred = cls.predict(X_test)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    accuracy = accuracy_score(y_test, y_pred)
    f1score = f1_score(y_test, y_pred, pos_label=1, average='macro')
    average_precision = average_precision_score(y_test, y_pred, average='weighted')
    ##print("Accuracy : ", accuracy)
    ##print("F1 Score : ", f1score)
    ##print("AUC : ", auc)
    ##print("Average Precision Recall: ", average_precision)
    ##print("")
    report = classification_report(y_test, y_pred, output_dict=True)
    df_report = pd.DataFrame(report).transpose()
    
    
    precision, recall, fscore, support = score(y_test, y_pred)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    specificity = tn / (tn+fp)
    ##print('Accuracy: {}'.format(np.round(accuracy * 100, 2)))
    ##print('Sensitivity: {}'.format(np.round(recall * 100, 2)))
    ##print('Specificity: {}'.format(np.round(specificity * 100, 2)))
    ##print('Precision: {}'.format(np.round(precision * 100, 2)))
    ##print('F1Score: {}'.format(np.round(fscore * 100, 2)))
    recall = np.round(recall, 4)
    precision = np.round(precision, 4)
    fscore = np.round(fscore, 4)
    imbalanced_result_table_test_f1 = imbalanced_result_table_test_f1.append({'Classifiers':str(cls)[0:3],
                                        'Accuracy':accuracy, 
                                        'Sensitivity':recall, 
                                        'Specificity':specificity, 
                                        'Precision':precision, 
                                        'F1Score':fscore,
                                        'AUC':auc, 
                                        'AveragePrecisionRecall':average_precision}, ignore_index=True)
    
# Set name of the classifiers as index labels
pd.options.display.max_columns = None
pd.set_option('display.expand_frame_repr', False)
imbalanced_result_table_test.set_index('classifiers', inplace=True)
#print(result_table_test)
#print(result_table_test_f1)
# Out:
# =====================================================================
# Classifier =  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# TEST SET
# [[7812  181]
#  [ 789  261]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      7993
#            1       0.59      0.25      0.35      1050
#
#     accuracy                           0.89      9043
#    macro avg       0.75      0.61      0.65      9043
# weighted avg       0.87      0.89      0.87      9043
#
# =====================================================================
# Classifier =  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)
# TEST SET
# [[7956   37]
#  [ 997   53]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      7993
#            1       0.59      0.05      0.09      1050
#
#     accuracy                           0.89      9043
#    macro avg       0.74      0.52      0.52      9043
# weighted avg       0.85      0.89      0.84      9043
#
# =====================================================================
# Classifier =  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)
# TEST SET
# [[7790  203]
#  [ 670  380]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      7993
#            1       0.65      0.36      0.47      1050
#
#     accuracy                           0.90      9043
#    macro avg       0.79      0.67      0.71      9043
# weighted avg       0.89      0.90      0.89      9043
#
# =====================================================================
# Classifier =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# TEST SET
# [[7741  252]
#  [ 600  450]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7993
#            1       0.64      0.43      0.51      1050
#
#     accuracy                           0.91      9043
#    macro avg       0.78      0.70      0.73      9043
# weighted avg       0.89      0.91      0.90      9043
#
# =====================================================================
# Classifier =  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=5000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# TEST SET
# [[7816  177]
#  [ 809  241]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      7993
#            1       0.58      0.23      0.33      1050
#
#     accuracy                           0.89      9043
#    macro avg       0.74      0.60      0.63      9043
# weighted avg       0.87      0.89      0.87      9043

# %%
# Results performance bar plot (Imbalanced Dataset)

color = ('#FF4136', '#2ECC40', '#FF851B', '#0074D9')
#FF851B orange, #FF4136 red, #0074D9, blue, #2ECC40 green)

# Function plotting the results performance
def plot_result(result_table, result_set, dataset):
  result_table = result_table.set_index('Classifiers')
  result_table = result_table.round(4)
  print('Imbalanced', result_set, 'set result:\n', result_table)
  #ax = result_table.plot.bar(color=color, figsize=(20, 9))
  #plt.xticks(rotation=0)
  #plt.ylabel("Performance", fontsize=15)
  #plt.xlabel("Classifiers", fontsize=15)
  #plt.ylim(0, 1.03)
  #plt.grid(True)
  #plt.legend(loc=2)
  #plt.title('{} Dataset - {} Set ({}) performance'.format(dataset, result_set, dataset_set), fontweight='bold', fontsize=15)
  
  i = 0
  label = np.round(result_table.Accuracy.values, 2)
  for p in ax.patches:
      ax.annotate(str(round(p.get_height(),2 )), (p.get_x() * 1.005, p.get_height() * 1.005), fontweight='bold', fontsize=12)
      i = i+1

  plt.show()            
  print("")

plot_result(imbalanced_result_table_test_f1, "Test", "Imbalanced")
# Out:
# Imbalanced Test set result:
#               Accuracy       Sensitivity  Specificity         Precision           F1Score     AUC  AveragePrecisionRecall
# Classifiers
# MLP            0.8927  [0.9774, 0.2486]       0.9774  [0.9083, 0.5905]  [0.9415, 0.3499]  0.8571                  0.2340
# SVC            0.8857  [0.9954, 0.0505]       0.9954  [0.8886, 0.5889]    [0.939, 0.093]  0.7029                  0.1400
# XGB            0.9035  [0.9746, 0.3619]       0.9746  [0.9208, 0.6518]  [0.9469, 0.4654]  0.9216                  0.3100
# Ran            0.9058  [0.9685, 0.4286]       0.9685   [0.9281, 0.641]  [0.9478, 0.5137]  0.9270                  0.3411
# Log            0.8910  [0.9779, 0.2295]       0.9779  [0.9062, 0.5766]  [0.9407, 0.3283]  0.8748                  0.2218

# %%
# # Plotting ROC/AUC

# # Function plotting AUC
# def plot_roc(result_table, result_set, dataset):
#   fig1 = plt.figure(1, figsize=(16,8))
#   for i in result_table.index:
#     plt.plot(result_table.loc[i]['fpr'], 
#              result_table.loc[i]['tpr'], 
#              label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
#   plt.plot([0,1], [0,1], color='orange', linestyle='--')
#   plt.xticks(np.arange(0.0, 1.1, step=0.1))
#   plt.xlabel("False Positive Rate", fontsize=15)
#   plt.yticks(np.arange(0.0, 1.1, step=0.1))
#   plt.ylabel("True Positive Rate", fontsize=15)
#   plt.title('{} Dataset - {} Set: ROC Chart'.format(dataset, result_set), fontweight='bold', fontsize=15)
#   plt.legend(prop={'size':13}, loc='lower right')

#   plt.show()
#   #fig.savefig('multiple_roc_curve.png')

# plot_roc(imbalanced_result_table_test, "Test", "Imbalanced")

# %% [markdown]
# # PSO Undersampling

# %%
# PSO undersampling using MIN/MAX distance
GBEST = "MAX"     # MIN or MAX
DROP = "SINGLE"   # SINGLE or DOUBLE

# Create 2 separate df for FLAG = 0 and 1
df_train = df.copy()

df_scaled_flag0 = df_train[df_train.New_Class == 0]
df_scaled_flag1 = df_train[df_train.New_Class == 1]

# Count total of FLAG 0 and 1
cnt_flag0 = df_train[df_train.New_Class == 0].count()[0]
cnt_flag1 = df_train[df_train.New_Class == 1].count()[0]

start_time = datetime.now() 
# PSO variables
max_particles_position = cnt_flag0
swarm_size = 10 # number of particles
row = 0
if (DROP == "DOUBLE"):
  n_rows = (cnt_flag0 - cnt_flag1) / 2
else:
  n_rows = cnt_flag0 - cnt_flag1
iteration = 0
n_iterations = 3
euc_distance = 0
fitness_candidate = 0
target = 1
target_error = 1e-6

# Variables to calculate the velocity
W = 0.5
c1 = 0.5
c2 = 0.9

df_scaled_flag0_gbest_final = pd.DataFrame([])

mytime = datetime.now(malaysia)
print(mytime)
print("Rows: ", n_rows, " ", "Max Particle Position/Flag0: ", max_particles_position, " ", "Flag1: ", cnt_flag1, " ", "No of Particles: ", swarm_size, " ", "No of Iteration: ", n_iterations)

while row < n_rows:
  start_time2 = datetime.now() 
  ###print("Row: ", row, " ", "Max Particle Position: ", max_particles_position, " ", "No of Particles: ", swarm_size, " ", "No of Iteration: ", n_iterations) 

# Define the fitness function. Calculate the distance between 2 rows using Euclidean Distance
  def fitness_function(position):
    distance = scipy.spatial.distance.cdist(df_scaled_flag0.iloc[[position[0]]], df_scaled_flag0.iloc[[position[1]]], metric='euclidean')
    #distance = scipy.spatial.distance.cdist(df_scaled_flag0.iloc[[position[0]]], df_scaled_flag0.iloc[[position[1]]], metric='minkowski')
    #distance = scipy.spatial.distance.cdist(df_scaled_flag0.iloc[[position[0]]], df_scaled_flag0.iloc[[position[1]]], metric='jaccard')
    distance = np.round(distance, 2)
    return(distance[0])

# Set velocity initial value 
  velocity_vector = ([np.array([0, 0]) for _ in range(swarm_size)])

# Generate number ranging between 0 to max_particles_position for 2 dimensions of an array
  particle_position_vector = np.random.randint(max_particles_position, size=(swarm_size, 2))

# Set initial particle position, initial pbest position and value, initial gbest and value
  pbest_position = particle_position_vector
  if (GBEST == "MIN"):
    pbest_fitness_value = np.array([float('inf') for _ in range(swarm_size)])   # MIN
    gbest_fitness_value = float('inf')                                          # MIN
  else:
    pbest_fitness_value = np.array([float() for _ in range(swarm_size)])        # MAX
    gbest_fitness_value = float()                                               # MAX

  gbest_position = np.array([float('inf'), float('inf')])
  best_iteration = np.array(float('inf'))
  pbest_final = np.array([])
  gbest_final = np.array([])

  iteration = 0
  while iteration < n_iterations:
    #print("Iteration ", iteration) 

    for i in range(swarm_size):
        fitness_candidate = fitness_function(particle_position_vector[i])
        #print(fitness_candidate, ' ', particle_position_vector[i], ' ', "iteration = ", iteration)
        
        if (fitness_candidate == 0.):
            #print("Fitness value equal", fitness_candidate, ' ', "Iteration = ", iteration)
            fitness_candidate = pbest_fitness_value[i]
        
        if (GBEST == "MIN"):
          if (pbest_fitness_value[i] > fitness_candidate):                      # MIN
            pbest_fitness_value[i] = fitness_candidate
            pbest_position[i] = particle_position_vector[i]
            pbest_result = np.array((pbest_position[i]))
            pbest_final = np.append(pbest_final, pbest_result)
            #print("Pbest =", pbest_fitness_value[i], ' ', "Pbest Position =", pbest_position[i], ' ', "Iterarion No =", iteration)

          if (gbest_fitness_value > fitness_candidate):                         # MIN
            gbest_fitness_value = fitness_candidate
            gbest_position = particle_position_vector[i]
            best_iteration = iteration
            gbest_result = np.array((gbest_position))
            gbest_final = np.append(gbest_final, gbest_result)
            #print("Gbest =", gbest_fitness_value, ' ', "Gbest Position =", gbest_position, ' ', "Iteration No =", iteration)
        else:
            if (pbest_fitness_value[i] < fitness_candidate):                    # MAX
              pbest_fitness_value[i] = fitness_candidate
              pbest_position[i] = particle_position_vector[i]
              pbest_result = np.array((pbest_position[i]))
              pbest_final = np.append(pbest_final, pbest_result)
              #print("Pbest =", pbest_fitness_value[i], ' ', "Pbest Position =", pbest_position[i], ' ', "Iterarion No =", iteration)

            if (gbest_fitness_value < fitness_candidate):                       # MAX
              gbest_fitness_value = fitness_candidate
              gbest_position = particle_position_vector[i]
              best_iteration = iteration
              gbest_result = np.array((gbest_position))
              gbest_final = np.append(gbest_final, gbest_result)
              #print("Gbest =", gbest_fitness_value, ' ', "Gbest Position =", gbest_position, ' ', "Iteration No =", iteration)
           
    if (abs(gbest_fitness_value - target) < target_error):
        break
        
    for i in range(swarm_size):
        new_velocity = (W * velocity_vector[i]) + (c1 * random.random()) * (pbest_position[i] - particle_position_vector[i]) + (c2 *random.random()) * (gbest_position - particle_position_vector[i])
        new_position = new_velocity + particle_position_vector[i]
        new_position = abs(np.round(new_position, 0))
        particle_position_vector[i] = new_position

    iteration = iteration + 1

  ###print("============================================================================================")
  print("The best position is", gbest_position,". The gbest value is", gbest_fitness_value, "in iteration number", best_iteration)       
  ###print("============================================================================================")
  #print("Gbest position", gbest_final)
  #print("=======================================================================================")
  #print("Pbest position", pbest_final)

  if (DROP == "DOUBLE"):
    df_scaled_flag0 = df_scaled_flag0.drop(df_scaled_flag0.index[gbest_position[1]])
    df_scaled_flag0 = df_scaled_flag0.drop(df_scaled_flag0.index[gbest_position[0]])
    max_particles_position = cnt_flag0 - 2  
  else:
    # Drop randomly 0 or 1
    r = random.randint(0, 1)
    df_scaled_flag0 = df_scaled_flag0.drop(df_scaled_flag0.index[gbest_position[r]])
    # Drop which has higher zero value
    #if (np.count_nonzero(df_scaled_flag0.iloc[[gbest_position[0]]]) <= np.count_nonzero(df_scaled_flag0.iloc[[gbest_position[1]]])):
    #  df_scaled_flag0 = df_scaled_flag0.drop(df_scaled_flag0.index[gbest_position[1]])
    #else:
    #  df_scaled_flag0 = df_scaled_flag0.drop(df_scaled_flag0.index[gbest_position[0]])
    max_particles_position = cnt_flag0 - 1

  cnt_flag0 = df_scaled_flag0.shape[0]
  print("df_scaled_flag0 rows: ", cnt_flag0, "/", cnt_flag1)
  
  #if (cnt_flag0 == cnt_flag1):
    #break

  #print("max_particles_position: ", max_particles_position)
  row = row + 1
  ###print('PSO Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time2))

print('PSO Iteration Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
df_scaled_flag0_gbest_final = df_scaled_flag0 
# Write to csv file
#df_scaled_flag0_gbest_final.to_csv("sgcc-pso-ANN-v5-gbest-min.csv")

mytime = datetime.now(malaysia)
print(mytime)
print("PSO Iteration DONE")
# Out:
# Streaming output truncated to the last 5000 lines.
# The best position is [3640 2373] . The gbest value is [603.18] in iteration number 0
# df_scaled_flag0 rows:  7786 / 5289
# The best position is [ 733 2922] . The gbest value is [585.06] in iteration number 0
# df_scaled_flag0 rows:  7785 / 5289
# The best position is [ 977 6755] . The gbest value is [787.05] in iteration number 1
# df_scaled_flag0 rows:  7784 / 5289
# The best position is [5734 2933] . The gbest value is [562.03] in iteration number 2
# df_scaled_flag0 rows:  7783 / 5289
# The best position is [6109 6668] . The gbest value is [588.8] in iteration number 2
# df_scaled_flag0 rows:  7782 / 5289
# The best position is [2209 4126] . The gbest value is [611.37] in iteration number 2
# df_scaled_flag0 rows:  7781 / 5289
# The best position is [3608 2512] . The gbest value is [584.34] in iteration number 1
# df_scaled_flag0 rows:  7780 / 5289
# The best position is [2438 2063] . The gbest value is [484.6] in iteration number 0
# df_scaled_flag0 rows:  7779 / 5289
# The best position is [2664  496] . The gbest value is [510.44] in iteration number 0
# df_scaled_flag0 rows:  7778 / 5289
# The best position is [2683 2898] . The gbest value is [600.31] in iteration number 2
# df_scaled_flag0 rows:  7777 / 5289
# The best position is [7767 5256] . The gbest value is [793.74] in iteration number 0
# df_scaled_flag0 rows:  7776 / 5289
# The best position is [1587 7438] . The gbest value is [565.52] in iteration number 0
# df_scaled_flag0 rows:  7775 / 5289
# The best position is [7363 2151] . The gbest value is [549.24] in iteration number 2
# df_scaled_flag0 rows:  7774 / 5289
# The best position is [1029 1838] . The gbest value is [592.52] in iteration number 0
# df_scaled_flag0 rows:  7773 / 5289
# The best position is [2791 7320] . The gbest value is [671.61] in iteration number 0
# df_scaled_flag0 rows:  7772 / 5289
# The best position is [1775 7202] . The gbest value is [634.73] in iteration number 0
# df_scaled_flag0 rows:  7771 / 5289
# The best position is [3570 5670] . The gbest value is [669.91] in iteration number 2
# df_scaled_flag0 rows:  7770 / 5289
# The best position is [6879 7068] . The gbest value is [921.34] in iteration number 1
# df_scaled_flag0 rows:  7769 / 5289
# The best position is [6653 5931] . The gbest value is [586.03] in iteration number 0
# df_scaled_flag0 rows:  7768 / 5289
# The best position is [2319 7022] . The gbest value is [695.32] in iteration number 2
# df_scaled_flag0 rows:  7767 / 5289
# The best position is [6735 2854] . The gbest value is [640.05] in iteration number 0
# df_scaled_flag0 rows:  7766 / 5289
# The best position is [3905 6108] . The gbest value is [605.31] in iteration number 1
# df_scaled_flag0 rows:  7765 / 5289
# The best position is [3090 3451] . The gbest value is [669.02] in iteration number 0
# df_scaled_flag0 rows:  7764 / 5289
# The best position is [5839 5294] . The gbest value is [627.2] in iteration number 2
# df_scaled_flag0 rows:  7763 / 5289
# The best position is [3644 5388] . The gbest value is [584.7] in iteration number 1
# df_scaled_flag0 rows:  7762 / 5289
# The best position is [6927 3086] . The gbest value is [665.75] in iteration number 0
# df_scaled_flag0 rows:  7761 / 5289
# The best position is [5503 5143] . The gbest value is [595.7] in iteration number 2
# df_scaled_flag0 rows:  7760 / 5289
# The best position is [ 137 4793] . The gbest value is [622.55] in iteration number 0
# df_scaled_flag0 rows:  7759 / 5289
# The best position is [849 969] . The gbest value is [719.18] in iteration number 0
# df_scaled_flag0 rows:  7758 / 5289
# The best position is [3837 6474] . The gbest value is [692.36] in iteration number 0
# df_scaled_flag0 rows:  7757 / 5289
# The best position is [3224 6670] . The gbest value is [653.44] in iteration number 2
# df_scaled_flag0 rows:  7756 / 5289
# The best position is [ 233 1391] . The gbest value is [647.27] in iteration number 0
# df_scaled_flag0 rows:  7755 / 5289
# The best position is [2070 7631] . The gbest value is [753.86] in iteration number 0
# df_scaled_flag0 rows:  7754 / 5289
# The best position is [ 453 5159] . The gbest value is [690.03] in iteration number 0
# df_scaled_flag0 rows:  7753 / 5289
# The best position is [2784 5315] . The gbest value is [561.94] in iteration number 1
# df_scaled_flag0 rows:  7752 / 5289
# The best position is [2485 1149] . The gbest value is [658.34] in iteration number 0
# df_scaled_flag0 rows:  7751 / 5289
# The best position is [4963 7706] . The gbest value is [722.92] in iteration number 0
# df_scaled_flag0 rows:  7750 / 5289
# The best position is [7705 1071] . The gbest value is [787.42] in iteration number 0
# df_scaled_flag0 rows:  7749 / 5289
# The best position is [1746 5767] . The gbest value is [688.31] in iteration number 1
# df_scaled_flag0 rows:  7748 / 5289
# The best position is [6906 6244] . The gbest value is [706.39] in iteration number 2
# df_scaled_flag0 rows:  7747 / 5289
# The best position is [3469 2346] . The gbest value is [681.39] in iteration number 1
# df_scaled_flag0 rows:  7746 / 5289
# The best position is [6073  533] . The gbest value is [647.29] in iteration number 2
# df_scaled_flag0 rows:  7745 / 5289
# The best position is [6734   69] . The gbest value is [862.07] in iteration number 0
# df_scaled_flag0 rows:  7744 / 5289
# The best position is [1475 5812] . The gbest value is [726.52] in iteration number 1
# df_scaled_flag0 rows:  7743 / 5289
# The best position is [2173 2717] . The gbest value is [643.81] in iteration number 1
# df_scaled_flag0 rows:  7742 / 5289
# The best position is [2115 2628] . The gbest value is [713.81] in iteration number 2
# df_scaled_flag0 rows:  7741 / 5289
# The best position is [2213 1340] . The gbest value is [597.21] in iteration number 0
# df_scaled_flag0 rows:  7740 / 5289
# The best position is [ 983 6781] . The gbest value is [594.12] in iteration number 0
# df_scaled_flag0 rows:  7739 / 5289
# The best position is [5974 3496] . The gbest value is [656.82] in iteration number 1
# df_scaled_flag0 rows:  7738 / 5289
# The best position is [7146 3293] . The gbest value is [541.22] in iteration number 2
# df_scaled_flag0 rows:  7737 / 5289
# The best position is [6471 5220] . The gbest value is [518.05] in iteration number 2
# df_scaled_flag0 rows:  7736 / 5289
# The best position is [4165 7684] . The gbest value is [455.77] in iteration number 0
# df_scaled_flag0 rows:  7735 / 5289
# The best position is [2391 6878] . The gbest value is [753.14] in iteration number 0
# df_scaled_flag0 rows:  7734 / 5289
# The best position is [5750 4050] . The gbest value is [519.8] in iteration number 0
# df_scaled_flag0 rows:  7733 / 5289
# The best position is [3979 2781] . The gbest value is [679.37] in iteration number 2
# df_scaled_flag0 rows:  7732 / 5289
# The best position is [5448 2363] . The gbest value is [741.63] in iteration number 1
# df_scaled_flag0 rows:  7731 / 5289
# The best position is [3322 7291] . The gbest value is [692.61] in iteration number 1
# df_scaled_flag0 rows:  7730 / 5289
# The best position is [5398 6181] . The gbest value is [582.99] in iteration number 2
# df_scaled_flag0 rows:  7729 / 5289
# The best position is [ 127 5749] . The gbest value is [580.76] in iteration number 0
# df_scaled_flag0 rows:  7728 / 5289
# The best position is [2994 4389] . The gbest value is [547.53] in iteration number 0
# df_scaled_flag0 rows:  7727 / 5289
# The best position is [5908 7525] . The gbest value is [682.09] in iteration number 0
# df_scaled_flag0 rows:  7726 / 5289
# The best position is [6068  580] . The gbest value is [626.03] in iteration number 0
# df_scaled_flag0 rows:  7725 / 5289
# The best position is [1691 4794] . The gbest value is [534.51] in iteration number 0
# df_scaled_flag0 rows:  7724 / 5289
# The best position is [7490 2566] . The gbest value is [612.7] in iteration number 1
# df_scaled_flag0 rows:  7723 / 5289
# The best position is [4089  159] . The gbest value is [657.41] in iteration number 0
# df_scaled_flag0 rows:  7722 / 5289
# The best position is [6515 7593] . The gbest value is [580.89] in iteration number 0
# df_scaled_flag0 rows:  7721 / 5289
# The best position is [3772 3746] . The gbest value is [543.84] in iteration number 0
# df_scaled_flag0 rows:  7720 / 5289
# The best position is [2181 4596] . The gbest value is [693.99] in iteration number 2
# df_scaled_flag0 rows:  7719 / 5289
# The best position is [2460 6530] . The gbest value is [710.34] in iteration number 0
# df_scaled_flag0 rows:  7718 / 5289
# The best position is [7070 1203] . The gbest value is [721.74] in iteration number 2
# df_scaled_flag0 rows:  7717 / 5289
# The best position is [6020 5849] . The gbest value is [562.86] in iteration number 1
# df_scaled_flag0 rows:  7716 / 5289
# The best position is [5789 1633] . The gbest value is [597.96] in iteration number 2
# df_scaled_flag0 rows:  7715 / 5289
# The best position is [3061 4446] . The gbest value is [495.19] in iteration number 0
# df_scaled_flag0 rows:  7714 / 5289
# The best position is [1768 6831] . The gbest value is [702.96] in iteration number 2
# df_scaled_flag0 rows:  7713 / 5289
# The best position is [5512 5312] . The gbest value is [544.11] in iteration number 0
# df_scaled_flag0 rows:  7712 / 5289
# The best position is [ 516 5539] . The gbest value is [639.16] in iteration number 0
# df_scaled_flag0 rows:  7711 / 5289
# The best position is [5512 6596] . The gbest value is [503.26] in iteration number 2
# df_scaled_flag0 rows:  7710 / 5289
# The best position is [6958 6395] . The gbest value is [723.51] in iteration number 0
# df_scaled_flag0 rows:  7709 / 5289
# The best position is [ 292 6557] . The gbest value is [737.7] in iteration number 0
# df_scaled_flag0 rows:  7708 / 5289
# The best position is [3366 5687] . The gbest value is [614.1] in iteration number 0
# df_scaled_flag0 rows:  7707 / 5289
# The best position is [3243 4604] . The gbest value is [578.16] in iteration number 0
# df_scaled_flag0 rows:  7706 / 5289
# The best position is [5644 4806] . The gbest value is [593.12] in iteration number 0
# df_scaled_flag0 rows:  7705 / 5289
# The best position is [5682 5041] . The gbest value is [532.12] in iteration number 0
# df_scaled_flag0 rows:  7704 / 5289
# The best position is [4932 2155] . The gbest value is [828.28] in iteration number 0
# df_scaled_flag0 rows:  7703 / 5289
# The best position is [ 648 2783] . The gbest value is [625.77] in iteration number 0
# df_scaled_flag0 rows:  7702 / 5289
# The best position is [4110 2464] . The gbest value is [596.75] in iteration number 1
# df_scaled_flag0 rows:  7701 / 5289
# The best position is [5137 3662] . The gbest value is [739.72] in iteration number 1
# df_scaled_flag0 rows:  7700 / 5289
# The best position is [7565 2641] . The gbest value is [634.74] in iteration number 0
# df_scaled_flag0 rows:  7699 / 5289
# The best position is [7158 2610] . The gbest value is [636.78] in iteration number 0
# df_scaled_flag0 rows:  7698 / 5289
# The best position is [4489 4413] . The gbest value is [680.98] in iteration number 1
# df_scaled_flag0 rows:  7697 / 5289
# The best position is [6855 5668] . The gbest value is [745.22] in iteration number 0
# df_scaled_flag0 rows:  7696 / 5289
# The best position is [5599 6392] . The gbest value is [557.42] in iteration number 0
# df_scaled_flag0 rows:  7695 / 5289
# The best position is [1739 3530] . The gbest value is [558.23] in iteration number 1
# df_scaled_flag0 rows:  7694 / 5289
# The best position is [3523 6477] . The gbest value is [585.46] in iteration number 1
# df_scaled_flag0 rows:  7693 / 5289
# The best position is [4117  988] . The gbest value is [621.55] in iteration number 1
# df_scaled_flag0 rows:  7692 / 5289
# The best position is [2203 3811] . The gbest value is [552.49] in iteration number 2
# df_scaled_flag0 rows:  7691 / 5289
# The best position is [3005 4055] . The gbest value is [744.89] in iteration number 1
# df_scaled_flag0 rows:  7690 / 5289
# The best position is [5788 3854] . The gbest value is [465.11] in iteration number 2
# df_scaled_flag0 rows:  7689 / 5289
# The best position is [ 813 3197] . The gbest value is [511.35] in iteration number 1
# df_scaled_flag0 rows:  7688 / 5289
# The best position is [1197 2912] . The gbest value is [554.05] in iteration number 1
# df_scaled_flag0 rows:  7687 / 5289
# The best position is [5989 2143] . The gbest value is [587.59] in iteration number 1
# df_scaled_flag0 rows:  7686 / 5289
# The best position is [4393 4768] . The gbest value is [600.19] in iteration number 0
# df_scaled_flag0 rows:  7685 / 5289
# The best position is [5314 6276] . The gbest value is [575.34] in iteration number 1
# df_scaled_flag0 rows:  7684 / 5289
# The best position is [5429 6644] . The gbest value is [648.27] in iteration number 2
# df_scaled_flag0 rows:  7683 / 5289
# The best position is [3822 2119] . The gbest value is [639.73] in iteration number 0
# df_scaled_flag0 rows:  7682 / 5289
# The best position is [3620 7371] . The gbest value is [586.34] in iteration number 2
# df_scaled_flag0 rows:  7681 / 5289
# The best position is [5900 2979] . The gbest value is [686.67] in iteration number 0
# df_scaled_flag0 rows:  7680 / 5289
# The best position is [4968 5552] . The gbest value is [568.95] in iteration number 1
# df_scaled_flag0 rows:  7679 / 5289
# The best position is [4942 5821] . The gbest value is [618.55] in iteration number 2
# df_scaled_flag0 rows:  7678 / 5289
# The best position is [5236 3677] . The gbest value is [749.55] in iteration number 2
# df_scaled_flag0 rows:  7677 / 5289
# The best position is [5023 2963] . The gbest value is [520.16] in iteration number 2
# df_scaled_flag0 rows:  7676 / 5289
# The best position is [6903 1139] . The gbest value is [660.35] in iteration number 1
# df_scaled_flag0 rows:  7675 / 5289
# The best position is [5779 4541] . The gbest value is [585.18] in iteration number 2
# df_scaled_flag0 rows:  7674 / 5289
# The best position is [3384 2049] . The gbest value is [650.98] in iteration number 0
# df_scaled_flag0 rows:  7673 / 5289
# The best position is [4803 7337] . The gbest value is [672.21] in iteration number 0
# df_scaled_flag0 rows:  7672 / 5289
# The best position is [3469 2726] . The gbest value is [592.88] in iteration number 0
# df_scaled_flag0 rows:  7671 / 5289
# The best position is [5705 5728] . The gbest value is [541.99] in iteration number 2
# df_scaled_flag0 rows:  7670 / 5289
# The best position is [2871 2236] . The gbest value is [631.] in iteration number 1
# df_scaled_flag0 rows:  7669 / 5289
# The best position is [1596 4410] . The gbest value is [529.88] in iteration number 1
# df_scaled_flag0 rows:  7668 / 5289
# The best position is [6822 4115] . The gbest value is [641.03] in iteration number 1
# df_scaled_flag0 rows:  7667 / 5289
# The best position is [6720 6690] . The gbest value is [774.09] in iteration number 2
# df_scaled_flag0 rows:  7666 / 5289
# The best position is [5185 4535] . The gbest value is [520.09] in iteration number 1
# df_scaled_flag0 rows:  7665 / 5289
# The best position is [3329  297] . The gbest value is [515.63] in iteration number 0
# df_scaled_flag0 rows:  7664 / 5289
# The best position is [4098 2068] . The gbest value is [528.62] in iteration number 1
# df_scaled_flag0 rows:  7663 / 5289
# The best position is [ 519 3393] . The gbest value is [698.] in iteration number 2
# df_scaled_flag0 rows:  7662 / 5289
# The best position is [ 292 2534] . The gbest value is [581.77] in iteration number 0
# df_scaled_flag0 rows:  7661 / 5289
# The best position is [3187 6637] . The gbest value is [866.65] in iteration number 1
# df_scaled_flag0 rows:  7660 / 5289
# The best position is [5215 1121] . The gbest value is [514.95] in iteration number 0
# df_scaled_flag0 rows:  7659 / 5289
# The best position is [5520  690] . The gbest value is [771.52] in iteration number 1
# df_scaled_flag0 rows:  7658 / 5289
# The best position is [4033 5279] . The gbest value is [613.43] in iteration number 2
# df_scaled_flag0 rows:  7657 / 5289
# The best position is [4342  525] . The gbest value is [600.62] in iteration number 2
# df_scaled_flag0 rows:  7656 / 5289
# The best position is [2810  709] . The gbest value is [683.47] in iteration number 2
# df_scaled_flag0 rows:  7655 / 5289
# The best position is [2140 6347] . The gbest value is [519.66] in iteration number 1
# df_scaled_flag0 rows:  7654 / 5289
# The best position is [4928  815] . The gbest value is [611.92] in iteration number 1
# df_scaled_flag0 rows:  7653 / 5289
# The best position is [5321 6829] . The gbest value is [739.54] in iteration number 0
# df_scaled_flag0 rows:  7652 / 5289
# The best position is [1291  624] . The gbest value is [610.47] in iteration number 0
# df_scaled_flag0 rows:  7651 / 5289
# The best position is [ 837 1083] . The gbest value is [658.72] in iteration number 2
# df_scaled_flag0 rows:  7650 / 5289
# The best position is [2566 6193] . The gbest value is [591.22] in iteration number 0
# df_scaled_flag0 rows:  7649 / 5289
# The best position is [6004 6700] . The gbest value is [701.48] in iteration number 2
# df_scaled_flag0 rows:  7648 / 5289
# The best position is [1099 4318] . The gbest value is [615.62] in iteration number 1
# df_scaled_flag0 rows:  7647 / 5289
# The best position is [3170 2743] . The gbest value is [635.47] in iteration number 2
# df_scaled_flag0 rows:  7646 / 5289
# The best position is [3273 3828] . The gbest value is [590.85] in iteration number 1
# df_scaled_flag0 rows:  7645 / 5289
# The best position is [6020 3786] . The gbest value is [504.14] in iteration number 2
# df_scaled_flag0 rows:  7644 / 5289
# The best position is [7506  168] . The gbest value is [731.02] in iteration number 0
# df_scaled_flag0 rows:  7643 / 5289
# The best position is [ 394 3624] . The gbest value is [612.65] in iteration number 0
# df_scaled_flag0 rows:  7642 / 5289
# The best position is [3766 3435] . The gbest value is [713.13] in iteration number 2
# df_scaled_flag0 rows:  7641 / 5289
# The best position is [6061 3307] . The gbest value is [521.43] in iteration number 0
# df_scaled_flag0 rows:  7640 / 5289
# The best position is [7378 4319] . The gbest value is [639.46] in iteration number 0
# df_scaled_flag0 rows:  7639 / 5289
# The best position is [4234 6830] . The gbest value is [620.42] in iteration number 0
# df_scaled_flag0 rows:  7638 / 5289
# The best position is [4255 6219] . The gbest value is [547.04] in iteration number 0
# df_scaled_flag0 rows:  7637 / 5289
# The best position is [2439 6133] . The gbest value is [798.93] in iteration number 1
# df_scaled_flag0 rows:  7636 / 5289
# The best position is [5957 5634] . The gbest value is [598.98] in iteration number 0
# df_scaled_flag0 rows:  7635 / 5289
# The best position is [6833  905] . The gbest value is [633.45] in iteration number 1
# df_scaled_flag0 rows:  7634 / 5289
# The best position is [4253 4800] . The gbest value is [593.25] in iteration number 1
# df_scaled_flag0 rows:  7633 / 5289
# The best position is [3603 5927] . The gbest value is [631.07] in iteration number 2
# df_scaled_flag0 rows:  7632 / 5289
# The best position is [3154 7360] . The gbest value is [460.08] in iteration number 0
# df_scaled_flag0 rows:  7631 / 5289
# The best position is [1934 6817] . The gbest value is [735.13] in iteration number 0
# df_scaled_flag0 rows:  7630 / 5289
# The best position is [2868 5149] . The gbest value is [584.45] in iteration number 2
# df_scaled_flag0 rows:  7629 / 5289
# The best position is [6006 1747] . The gbest value is [453.08] in iteration number 0
# df_scaled_flag0 rows:  7628 / 5289
# The best position is [1720 5513] . The gbest value is [641.36] in iteration number 0
# df_scaled_flag0 rows:  7627 / 5289
# The best position is [3013 2825] . The gbest value is [614.43] in iteration number 2
# df_scaled_flag0 rows:  7626 / 5289
# The best position is [2723 3749] . The gbest value is [619.34] in iteration number 1
# df_scaled_flag0 rows:  7625 / 5289
# The best position is [5233 3372] . The gbest value is [590.8] in iteration number 2
# df_scaled_flag0 rows:  7624 / 5289
# The best position is [6407 5960] . The gbest value is [498.77] in iteration number 1
# df_scaled_flag0 rows:  7623 / 5289
# The best position is [1448 3499] . The gbest value is [545.32] in iteration number 2
# df_scaled_flag0 rows:  7622 / 5289
# The best position is [3127 6197] . The gbest value is [647.7] in iteration number 1
# df_scaled_flag0 rows:  7621 / 5289
# The best position is [5188 7402] . The gbest value is [688.98] in iteration number 0
# df_scaled_flag0 rows:  7620 / 5289
# The best position is [2652 1830] . The gbest value is [484.35] in iteration number 2
# df_scaled_flag0 rows:  7619 / 5289
# The best position is [1281 5981] . The gbest value is [646.41] in iteration number 1
# df_scaled_flag0 rows:  7618 / 5289
# The best position is [5172 7364] . The gbest value is [534.75] in iteration number 0
# df_scaled_flag0 rows:  7617 / 5289
# The best position is [6970 4413] . The gbest value is [680.27] in iteration number 2
# df_scaled_flag0 rows:  7616 / 5289
# The best position is [4124 5838] . The gbest value is [637.19] in iteration number 0
# df_scaled_flag0 rows:  7615 / 5289
# The best position is [4789 3248] . The gbest value is [557.09] in iteration number 1
# df_scaled_flag0 rows:  7614 / 5289
# The best position is [981 138] . The gbest value is [451.87] in iteration number 0
# df_scaled_flag0 rows:  7613 / 5289
# The best position is [ 111 7267] . The gbest value is [632.15] in iteration number 0
# df_scaled_flag0 rows:  7612 / 5289
# The best position is [2756 1511] . The gbest value is [604.21] in iteration number 0
# df_scaled_flag0 rows:  7611 / 5289
# The best position is [7492  415] . The gbest value is [837.37] in iteration number 0
# df_scaled_flag0 rows:  7610 / 5289
# The best position is [1743 7488] . The gbest value is [821.9] in iteration number 0
# df_scaled_flag0 rows:  7609 / 5289
# The best position is [1534 4288] . The gbest value is [600.7] in iteration number 0
# df_scaled_flag0 rows:  7608 / 5289
# The best position is [3219 3516] . The gbest value is [559.71] in iteration number 2
# df_scaled_flag0 rows:  7607 / 5289
# The best position is [6451 3324] . The gbest value is [591.99] in iteration number 2
# df_scaled_flag0 rows:  7606 / 5289
# The best position is [3491 6222] . The gbest value is [523.16] in iteration number 1
# df_scaled_flag0 rows:  7605 / 5289
# The best position is [3489 6630] . The gbest value is [534.16] in iteration number 1
# df_scaled_flag0 rows:  7604 / 5289
# The best position is [1697 5490] . The gbest value is [444.21] in iteration number 1
# df_scaled_flag0 rows:  7603 / 5289
# The best position is [4581 4378] . The gbest value is [555.82] in iteration number 2
# df_scaled_flag0 rows:  7602 / 5289
# The best position is [4374 3077] . The gbest value is [665.62] in iteration number 2
# df_scaled_flag0 rows:  7601 / 5289
# The best position is [3931 5866] . The gbest value is [514.64] in iteration number 0
# df_scaled_flag0 rows:  7600 / 5289
# The best position is [2055 2755] . The gbest value is [627.76] in iteration number 2
# df_scaled_flag0 rows:  7599 / 5289
# The best position is [ 630 3462] . The gbest value is [452.6] in iteration number 0
# df_scaled_flag0 rows:  7598 / 5289
# The best position is [4157 3833] . The gbest value is [704.43] in iteration number 1
# df_scaled_flag0 rows:  7597 / 5289
# The best position is [2260 3665] . The gbest value is [521.53] in iteration number 2
# df_scaled_flag0 rows:  7596 / 5289
# The best position is [4741 6330] . The gbest value is [616.66] in iteration number 2
# df_scaled_flag0 rows:  7595 / 5289
# The best position is [3165 7441] . The gbest value is [733.08] in iteration number 0
# df_scaled_flag0 rows:  7594 / 5289
# The best position is [5196 4091] . The gbest value is [503.04] in iteration number 1
# df_scaled_flag0 rows:  7593 / 5289
# The best position is [5686 5368] . The gbest value is [612.49] in iteration number 0
# df_scaled_flag0 rows:  7592 / 5289
# The best position is [6905 3078] . The gbest value is [516.43] in iteration number 1
# df_scaled_flag0 rows:  7591 / 5289
# The best position is [2140 6115] . The gbest value is [498.72] in iteration number 0
# df_scaled_flag0 rows:  7590 / 5289
# The best position is [4517 1604] . The gbest value is [520.25] in iteration number 1
# df_scaled_flag0 rows:  7589 / 5289
# The best position is [1634 5098] . The gbest value is [626.9] in iteration number 2
# df_scaled_flag0 rows:  7588 / 5289
# The best position is [1485  741] . The gbest value is [475.22] in iteration number 2
# df_scaled_flag0 rows:  7587 / 5289
# The best position is [5768 3439] . The gbest value is [582.94] in iteration number 2
# df_scaled_flag0 rows:  7586 / 5289
# The best position is [6108 3514] . The gbest value is [666.29] in iteration number 1
# df_scaled_flag0 rows:  7585 / 5289
# The best position is [1714 4573] . The gbest value is [674.79] in iteration number 2
# df_scaled_flag0 rows:  7584 / 5289
# The best position is [ 752 5497] . The gbest value is [491.62] in iteration number 1
# df_scaled_flag0 rows:  7583 / 5289
# The best position is [3810 3989] . The gbest value is [621.26] in iteration number 1
# df_scaled_flag0 rows:  7582 / 5289
# The best position is [4987 5932] . The gbest value is [603.26] in iteration number 0
# df_scaled_flag0 rows:  7581 / 5289
# The best position is [4363 5473] . The gbest value is [569.72] in iteration number 0
# df_scaled_flag0 rows:  7580 / 5289
# The best position is [4771 2945] . The gbest value is [603.72] in iteration number 2
# df_scaled_flag0 rows:  7579 / 5289
# The best position is [5643 1833] . The gbest value is [493.45] in iteration number 2
# df_scaled_flag0 rows:  7578 / 5289
# The best position is [1666 3092] . The gbest value is [514.73] in iteration number 0
# df_scaled_flag0 rows:  7577 / 5289
# The best position is [2162 2734] . The gbest value is [628.75] in iteration number 1
# df_scaled_flag0 rows:  7576 / 5289
# The best position is [1262 2176] . The gbest value is [549.97] in iteration number 1
# df_scaled_flag0 rows:  7575 / 5289
# The best position is [6419 1073] . The gbest value is [536.37] in iteration number 0
# df_scaled_flag0 rows:  7574 / 5289
# The best position is [5625 2577] . The gbest value is [729.31] in iteration number 1
# df_scaled_flag0 rows:  7573 / 5289
# The best position is [2114 6309] . The gbest value is [554.64] in iteration number 1
# df_scaled_flag0 rows:  7572 / 5289
# The best position is [1269 6871] . The gbest value is [699.02] in iteration number 0
# df_scaled_flag0 rows:  7571 / 5289
# The best position is [5990 3047] . The gbest value is [631.59] in iteration number 1
# df_scaled_flag0 rows:  7570 / 5289
# The best position is [4544 5946] . The gbest value is [802.13] in iteration number 0
# df_scaled_flag0 rows:  7569 / 5289
# The best position is [1219 7155] . The gbest value is [619.16] in iteration number 0
# df_scaled_flag0 rows:  7568 / 5289
# The best position is [3826 4177] . The gbest value is [483.43] in iteration number 1
# df_scaled_flag0 rows:  7567 / 5289
# The best position is [6989 6705] . The gbest value is [807.83] in iteration number 0
# df_scaled_flag0 rows:  7566 / 5289
# The best position is [3377 2376] . The gbest value is [592.36] in iteration number 1
# df_scaled_flag0 rows:  7565 / 5289
# The best position is [6072 1581] . The gbest value is [732.08] in iteration number 2
# df_scaled_flag0 rows:  7564 / 5289
# The best position is [2729 6497] . The gbest value is [513.04] in iteration number 1
# df_scaled_flag0 rows:  7563 / 5289
# The best position is [6855 4482] . The gbest value is [593.95] in iteration number 2
# df_scaled_flag0 rows:  7562 / 5289
# The best position is [2120 2411] . The gbest value is [670.63] in iteration number 2
# df_scaled_flag0 rows:  7561 / 5289
# The best position is [4214 7414] . The gbest value is [656.01] in iteration number 1
# df_scaled_flag0 rows:  7560 / 5289
# The best position is [1889 2909] . The gbest value is [508.33] in iteration number 0
# df_scaled_flag0 rows:  7559 / 5289
# The best position is [4977 2576] . The gbest value is [533.26] in iteration number 1
# df_scaled_flag0 rows:  7558 / 5289
# The best position is [2421 5782] . The gbest value is [584.3] in iteration number 2
# df_scaled_flag0 rows:  7557 / 5289
# The best position is [5585 4990] . The gbest value is [551.32] in iteration number 2
# df_scaled_flag0 rows:  7556 / 5289
# The best position is [5305 4728] . The gbest value is [651.56] in iteration number 2
# df_scaled_flag0 rows:  7555 / 5289
# The best position is [1848 6693] . The gbest value is [544.12] in iteration number 0
# df_scaled_flag0 rows:  7554 / 5289
# The best position is [2789 3547] . The gbest value is [752.66] in iteration number 0
# df_scaled_flag0 rows:  7553 / 5289
# The best position is [1584 5289] . The gbest value is [613.66] in iteration number 1
# df_scaled_flag0 rows:  7552 / 5289
# The best position is [1154 4301] . The gbest value is [800.11] in iteration number 1
# df_scaled_flag0 rows:  7551 / 5289
# The best position is [4477 3811] . The gbest value is [614.49] in iteration number 2
# df_scaled_flag0 rows:  7550 / 5289
# The best position is [6745 4339] . The gbest value is [579.22] in iteration number 1
# df_scaled_flag0 rows:  7549 / 5289
# The best position is [5795 2782] . The gbest value is [650.79] in iteration number 2
# df_scaled_flag0 rows:  7548 / 5289
# The best position is [1921 5587] . The gbest value is [492.16] in iteration number 1
# df_scaled_flag0 rows:  7547 / 5289
# The best position is [3596 5727] . The gbest value is [529.82] in iteration number 1
# df_scaled_flag0 rows:  7546 / 5289
# The best position is [7134 7399] . The gbest value is [781.75] in iteration number 0
# df_scaled_flag0 rows:  7545 / 5289
# The best position is [5550 4819] . The gbest value is [654.06] in iteration number 1
# df_scaled_flag0 rows:  7544 / 5289
# The best position is [ 71 163] . The gbest value is [592.18] in iteration number 0
# df_scaled_flag0 rows:  7543 / 5289
# The best position is [3284 5521] . The gbest value is [584.46] in iteration number 2
# df_scaled_flag0 rows:  7542 / 5289
# The best position is [3896  777] . The gbest value is [665.06] in iteration number 1
# df_scaled_flag0 rows:  7541 / 5289
# The best position is [1580 5486] . The gbest value is [713.42] in iteration number 1
# df_scaled_flag0 rows:  7540 / 5289
# The best position is [3011 2802] . The gbest value is [551.51] in iteration number 0
# df_scaled_flag0 rows:  7539 / 5289
# The best position is [6435 3192] . The gbest value is [597.01] in iteration number 2
# df_scaled_flag0 rows:  7538 / 5289
# The best position is [3843 2241] . The gbest value is [497.03] in iteration number 1
# df_scaled_flag0 rows:  7537 / 5289
# The best position is [3508 2967] . The gbest value is [523.64] in iteration number 2
# df_scaled_flag0 rows:  7536 / 5289
# The best position is [2352 4805] . The gbest value is [769.66] in iteration number 1
# df_scaled_flag0 rows:  7535 / 5289
# The best position is [3644 5781] . The gbest value is [626.24] in iteration number 0
# df_scaled_flag0 rows:  7534 / 5289
# The best position is [2397 1995] . The gbest value is [507.49] in iteration number 1
# df_scaled_flag0 rows:  7533 / 5289
# The best position is [5649  336] . The gbest value is [553.63] in iteration number 0
# df_scaled_flag0 rows:  7532 / 5289
# The best position is [5592  191] . The gbest value is [646.1] in iteration number 0
# df_scaled_flag0 rows:  7531 / 5289
# The best position is [1560 7042] . The gbest value is [776.99] in iteration number 2
# df_scaled_flag0 rows:  7530 / 5289
# The best position is [4987 2927] . The gbest value is [551.04] in iteration number 1
# df_scaled_flag0 rows:  7529 / 5289
# The best position is [1553 5731] . The gbest value is [629.01] in iteration number 1
# df_scaled_flag0 rows:  7528 / 5289
# The best position is [ 277 3701] . The gbest value is [516.53] in iteration number 1
# df_scaled_flag0 rows:  7527 / 5289
# The best position is [6908 6809] . The gbest value is [546.27] in iteration number 0
# df_scaled_flag0 rows:  7526 / 5289
# The best position is [1189  417] . The gbest value is [672.27] in iteration number 0
# df_scaled_flag0 rows:  7525 / 5289
# The best position is [6036 7206] . The gbest value is [707.51] in iteration number 0
# df_scaled_flag0 rows:  7524 / 5289
# The best position is [7238 3175] . The gbest value is [608.68] in iteration number 1
# df_scaled_flag0 rows:  7523 / 5289
# The best position is [1216  403] . The gbest value is [580.95] in iteration number 0
# df_scaled_flag0 rows:  7522 / 5289
# The best position is [5226 1573] . The gbest value is [606.48] in iteration number 1
# df_scaled_flag0 rows:  7521 / 5289
# The best position is [5061 6549] . The gbest value is [712.42] in iteration number 1
# df_scaled_flag0 rows:  7520 / 5289
# The best position is [ 859 3464] . The gbest value is [615.05] in iteration number 2
# df_scaled_flag0 rows:  7519 / 5289
# The best position is [2061  857] . The gbest value is [739.12] in iteration number 1
# df_scaled_flag0 rows:  7518 / 5289
# The best position is [1490 1332] . The gbest value is [639.55] in iteration number 0
# df_scaled_flag0 rows:  7517 / 5289
# The best position is [5317 3144] . The gbest value is [567.2] in iteration number 2
# df_scaled_flag0 rows:  7516 / 5289
# The best position is [2601 6641] . The gbest value is [568.73] in iteration number 2
# df_scaled_flag0 rows:  7515 / 5289
# The best position is [ 608 3301] . The gbest value is [629.69] in iteration number 2
# df_scaled_flag0 rows:  7514 / 5289
# The best position is [5467 6666] . The gbest value is [634.25] in iteration number 2
# df_scaled_flag0 rows:  7513 / 5289
# The best position is [6569 4819] . The gbest value is [626.36] in iteration number 1
# df_scaled_flag0 rows:  7512 / 5289
# The best position is [2159 3617] . The gbest value is [574.25] in iteration number 1
# df_scaled_flag0 rows:  7511 / 5289
# The best position is [4412 3535] . The gbest value is [520.3] in iteration number 0
# df_scaled_flag0 rows:  7510 / 5289
# The best position is [349  31] . The gbest value is [530.96] in iteration number 0
# df_scaled_flag0 rows:  7509 / 5289
# The best position is [1912 5493] . The gbest value is [563.01] in iteration number 0
# df_scaled_flag0 rows:  7508 / 5289
# The best position is [5961 1631] . The gbest value is [582.01] in iteration number 0
# df_scaled_flag0 rows:  7507 / 5289
# The best position is [2858 4827] . The gbest value is [694.6] in iteration number 1
# df_scaled_flag0 rows:  7506 / 5289
# The best position is [4298 6092] . The gbest value is [597.71] in iteration number 0
# df_scaled_flag0 rows:  7505 / 5289
# The best position is [5682  997] . The gbest value is [538.9] in iteration number 2
# df_scaled_flag0 rows:  7504 / 5289
# The best position is [4139  817] . The gbest value is [634.35] in iteration number 0
# df_scaled_flag0 rows:  7503 / 5289
# The best position is [7470 2911] . The gbest value is [731.55] in iteration number 0
# df_scaled_flag0 rows:  7502 / 5289
# The best position is [4660 1207] . The gbest value is [648.46] in iteration number 2
# df_scaled_flag0 rows:  7501 / 5289
# The best position is [1787 1777] . The gbest value is [708.27] in iteration number 1
# df_scaled_flag0 rows:  7500 / 5289
# The best position is [7427 6686] . The gbest value is [624.44] in iteration number 0
# df_scaled_flag0 rows:  7499 / 5289
# The best position is [1537  421] . The gbest value is [473.37] in iteration number 0
# df_scaled_flag0 rows:  7498 / 5289
# The best position is [5951 2014] . The gbest value is [578.6] in iteration number 2
# df_scaled_flag0 rows:  7497 / 5289
# The best position is [2950 4605] . The gbest value is [510.17] in iteration number 0
# df_scaled_flag0 rows:  7496 / 5289
# The best position is [5191 6181] . The gbest value is [635.79] in iteration number 2
# df_scaled_flag0 rows:  7495 / 5289
# The best position is [3170 5758] . The gbest value is [584.59] in iteration number 2
# df_scaled_flag0 rows:  7494 / 5289
# The best position is [1951 5949] . The gbest value is [519.13] in iteration number 1
# df_scaled_flag0 rows:  7493 / 5289
# The best position is [1682 4180] . The gbest value is [593.21] in iteration number 1
# df_scaled_flag0 rows:  7492 / 5289
# The best position is [7051 2823] . The gbest value is [775.37] in iteration number 1
# df_scaled_flag0 rows:  7491 / 5289
# The best position is [6943 3383] . The gbest value is [721.87] in iteration number 0
# df_scaled_flag0 rows:  7490 / 5289
# The best position is [3286 7041] . The gbest value is [650.97] in iteration number 1
# df_scaled_flag0 rows:  7489 / 5289
# The best position is [3241 2758] . The gbest value is [588.29] in iteration number 0
# df_scaled_flag0 rows:  7488 / 5289
# The best position is [1516 6162] . The gbest value is [620.31] in iteration number 1
# df_scaled_flag0 rows:  7487 / 5289
# The best position is [2737 2507] . The gbest value is [575.96] in iteration number 1
# df_scaled_flag0 rows:  7486 / 5289
# The best position is [4835 3447] . The gbest value is [531.8] in iteration number 1
# df_scaled_flag0 rows:  7485 / 5289
# The best position is [1532 3189] . The gbest value is [575.47] in iteration number 1
# df_scaled_flag0 rows:  7484 / 5289
# The best position is [1216 7071] . The gbest value is [530.51] in iteration number 0
# df_scaled_flag0 rows:  7483 / 5289
# The best position is [1664 5810] . The gbest value is [605.53] in iteration number 2
# df_scaled_flag0 rows:  7482 / 5289
# The best position is [4101 2528] . The gbest value is [488.01] in iteration number 1
# df_scaled_flag0 rows:  7481 / 5289
# The best position is [459 708] . The gbest value is [749.93] in iteration number 0
# df_scaled_flag0 rows:  7480 / 5289
# The best position is [1543 4886] . The gbest value is [629.37] in iteration number 0
# df_scaled_flag0 rows:  7479 / 5289
# The best position is [3266 5898] . The gbest value is [526.13] in iteration number 0
# df_scaled_flag0 rows:  7478 / 5289
# The best position is [6519  156] . The gbest value is [724.82] in iteration number 1
# df_scaled_flag0 rows:  7477 / 5289
# The best position is [6556 4082] . The gbest value is [516.58] in iteration number 0
# df_scaled_flag0 rows:  7476 / 5289
# The best position is [4442 4835] . The gbest value is [668.97] in iteration number 1
# df_scaled_flag0 rows:  7475 / 5289
# The best position is [1767 5538] . The gbest value is [615.06] in iteration number 1
# df_scaled_flag0 rows:  7474 / 5289
# The best position is [4836 5484] . The gbest value is [454.3] in iteration number 2
# df_scaled_flag0 rows:  7473 / 5289
# The best position is [6389 4599] . The gbest value is [618.09] in iteration number 1
# df_scaled_flag0 rows:  7472 / 5289
# The best position is [5295 4836] . The gbest value is [582.31] in iteration number 1
# df_scaled_flag0 rows:  7471 / 5289
# The best position is [2700  646] . The gbest value is [555.27] in iteration number 1
# df_scaled_flag0 rows:  7470 / 5289
# The best position is [3440 1792] . The gbest value is [490.96] in iteration number 0
# df_scaled_flag0 rows:  7469 / 5289
# The best position is [1976 4608] . The gbest value is [516.39] in iteration number 2
# df_scaled_flag0 rows:  7468 / 5289
# The best position is [4431 1718] . The gbest value is [454.71] in iteration number 1
# df_scaled_flag0 rows:  7467 / 5289
# The best position is [5847  946] . The gbest value is [574.75] in iteration number 0
# df_scaled_flag0 rows:  7466 / 5289
# The best position is [3427 2078] . The gbest value is [619.05] in iteration number 2
# df_scaled_flag0 rows:  7465 / 5289
# The best position is [7301 6221] . The gbest value is [887.23] in iteration number 0
# df_scaled_flag0 rows:  7464 / 5289
# The best position is [2537 2488] . The gbest value is [773.48] in iteration number 2
# df_scaled_flag0 rows:  7463 / 5289
# The best position is [4570 1226] . The gbest value is [622.67] in iteration number 1
# df_scaled_flag0 rows:  7462 / 5289
# The best position is [6492 5092] . The gbest value is [731.04] in iteration number 0
# df_scaled_flag0 rows:  7461 / 5289
# The best position is [3263 3220] . The gbest value is [521.58] in iteration number 2
# df_scaled_flag0 rows:  7460 / 5289
# The best position is [6038 3490] . The gbest value is [582.02] in iteration number 2
# df_scaled_flag0 rows:  7459 / 5289
# The best position is [2220 1216] . The gbest value is [679.69] in iteration number 2
# df_scaled_flag0 rows:  7458 / 5289
# The best position is [4551 2534] . The gbest value is [709.81] in iteration number 1
# df_scaled_flag0 rows:  7457 / 5289
# The best position is [  29 1255] . The gbest value is [663.06] in iteration number 0
# df_scaled_flag0 rows:  7456 / 5289
# The best position is [5910 5570] . The gbest value is [578.22] in iteration number 0
# df_scaled_flag0 rows:  7455 / 5289
# The best position is [6122 3677] . The gbest value is [561.3] in iteration number 0
# df_scaled_flag0 rows:  7454 / 5289
# The best position is [4923 2378] . The gbest value is [424.03] in iteration number 0
# df_scaled_flag0 rows:  7453 / 5289
# The best position is [1169 2887] . The gbest value is [712.25] in iteration number 1
# df_scaled_flag0 rows:  7452 / 5289
# The best position is [1752 3515] . The gbest value is [653.3] in iteration number 1
# df_scaled_flag0 rows:  7451 / 5289
# The best position is [1257 2457] . The gbest value is [567.34] in iteration number 0
# df_scaled_flag0 rows:  7450 / 5289
# The best position is [6493 4969] . The gbest value is [718.07] in iteration number 1
# df_scaled_flag0 rows:  7449 / 5289
# The best position is [1831 7226] . The gbest value is [542.51] in iteration number 0
# df_scaled_flag0 rows:  7448 / 5289
# The best position is [1873 6348] . The gbest value is [797.77] in iteration number 0
# df_scaled_flag0 rows:  7447 / 5289
# The best position is [3682 5527] . The gbest value is [662.91] in iteration number 1
# df_scaled_flag0 rows:  7446 / 5289
# The best position is [540 870] . The gbest value is [595.94] in iteration number 2
# df_scaled_flag0 rows:  7445 / 5289
# The best position is [3659 5163] . The gbest value is [627.18] in iteration number 1
# df_scaled_flag0 rows:  7444 / 5289
# The best position is [4295 1691] . The gbest value is [607.76] in iteration number 1
# df_scaled_flag0 rows:  7443 / 5289
# The best position is [1806 3268] . The gbest value is [556.95] in iteration number 1
# df_scaled_flag0 rows:  7442 / 5289
# The best position is [901 436] . The gbest value is [658.46] in iteration number 0
# df_scaled_flag0 rows:  7441 / 5289
# The best position is [3102 2036] . The gbest value is [587.41] in iteration number 0
# df_scaled_flag0 rows:  7440 / 5289
# The best position is [6153   15] . The gbest value is [583.19] in iteration number 0
# df_scaled_flag0 rows:  7439 / 5289
# The best position is [7025 3548] . The gbest value is [567.76] in iteration number 0
# df_scaled_flag0 rows:  7438 / 5289
# The best position is [3688 2603] . The gbest value is [661.4] in iteration number 0
# df_scaled_flag0 rows:  7437 / 5289
# The best position is [2812  239] . The gbest value is [621.77] in iteration number 0
# df_scaled_flag0 rows:  7436 / 5289
# The best position is [5203 3029] . The gbest value is [616.78] in iteration number 0
# df_scaled_flag0 rows:  7435 / 5289
# The best position is [6130 6389] . The gbest value is [522.41] in iteration number 2
# df_scaled_flag0 rows:  7434 / 5289
# The best position is [5862 4440] . The gbest value is [927.26] in iteration number 1
# df_scaled_flag0 rows:  7433 / 5289
# The best position is [2958 6914] . The gbest value is [654.97] in iteration number 1
# df_scaled_flag0 rows:  7432 / 5289
# The best position is [5697 2409] . The gbest value is [710.63] in iteration number 2
# df_scaled_flag0 rows:  7431 / 5289
# The best position is [1411 6757] . The gbest value is [709.82] in iteration number 0
# df_scaled_flag0 rows:  7430 / 5289
# The best position is [5185 5689] . The gbest value is [579.74] in iteration number 0
# df_scaled_flag0 rows:  7429 / 5289
# The best position is [5284 5447] . The gbest value is [628.36] in iteration number 2
# df_scaled_flag0 rows:  7428 / 5289
# The best position is [1309 6536] . The gbest value is [579.] in iteration number 1
# df_scaled_flag0 rows:  7427 / 5289
# The best position is [ 969 2613] . The gbest value is [558.38] in iteration number 2
# df_scaled_flag0 rows:  7426 / 5289
# The best position is [3262 6784] . The gbest value is [659.74] in iteration number 2
# df_scaled_flag0 rows:  7425 / 5289
# The best position is [3643 3163] . The gbest value is [529.2] in iteration number 0
# df_scaled_flag0 rows:  7424 / 5289
# The best position is [6513 6090] . The gbest value is [594.12] in iteration number 1
# df_scaled_flag0 rows:  7423 / 5289
# The best position is [4024 1623] . The gbest value is [596.97] in iteration number 2
# df_scaled_flag0 rows:  7422 / 5289
# The best position is [5459   86] . The gbest value is [531.46] in iteration number 0
# df_scaled_flag0 rows:  7421 / 5289
# The best position is [2056  980] . The gbest value is [684.36] in iteration number 0
# df_scaled_flag0 rows:  7420 / 5289
# The best position is [3013 3882] . The gbest value is [500.38] in iteration number 1
# df_scaled_flag0 rows:  7419 / 5289
# The best position is [1082 6304] . The gbest value is [573.22] in iteration number 1
# df_scaled_flag0 rows:  7418 / 5289
# The best position is [ 567 1824] . The gbest value is [572.08] in iteration number 2
# df_scaled_flag0 rows:  7417 / 5289
# The best position is [5800 3548] . The gbest value is [602.3] in iteration number 0
# df_scaled_flag0 rows:  7416 / 5289
# The best position is [5092 6650] . The gbest value is [556.14] in iteration number 0
# df_scaled_flag0 rows:  7415 / 5289
# The best position is [1614 4255] . The gbest value is [547.79] in iteration number 1
# df_scaled_flag0 rows:  7414 / 5289
# The best position is [3885  771] . The gbest value is [624.28] in iteration number 0
# df_scaled_flag0 rows:  7413 / 5289
# The best position is [1782 2053] . The gbest value is [515.47] in iteration number 0
# df_scaled_flag0 rows:  7412 / 5289
# The best position is [6685  178] . The gbest value is [710.87] in iteration number 0
# df_scaled_flag0 rows:  7411 / 5289
# The best position is [342 761] . The gbest value is [503.45] in iteration number 0
# df_scaled_flag0 rows:  7410 / 5289
# The best position is [5725 3692] . The gbest value is [790.41] in iteration number 1
# df_scaled_flag0 rows:  7409 / 5289
# The best position is [7258 3252] . The gbest value is [780.08] in iteration number 0
# df_scaled_flag0 rows:  7408 / 5289
# The best position is [5702 5212] . The gbest value is [552.57] in iteration number 1
# df_scaled_flag0 rows:  7407 / 5289
# The best position is [3271 6563] . The gbest value is [574.21] in iteration number 1
# df_scaled_flag0 rows:  7406 / 5289
# The best position is [3326 2286] . The gbest value is [570.38] in iteration number 0
# df_scaled_flag0 rows:  7405 / 5289
# The best position is [3999 5375] . The gbest value is [592.8] in iteration number 1
# df_scaled_flag0 rows:  7404 / 5289
# The best position is [4514 3632] . The gbest value is [481.29] in iteration number 2
# df_scaled_flag0 rows:  7403 / 5289
# The best position is [933 708] . The gbest value is [670.07] in iteration number 0
# df_scaled_flag0 rows:  7402 / 5289
# The best position is [ 523 2461] . The gbest value is [669.93] in iteration number 0
# df_scaled_flag0 rows:  7401 / 5289
# The best position is [4602 4421] . The gbest value is [620.42] in iteration number 0
# df_scaled_flag0 rows:  7400 / 5289
# The best position is [6901 1028] . The gbest value is [653.86] in iteration number 0
# df_scaled_flag0 rows:  7399 / 5289
# The best position is [5456  463] . The gbest value is [755.03] in iteration number 0
# df_scaled_flag0 rows:  7398 / 5289
# The best position is [1544 4917] . The gbest value is [595.27] in iteration number 2
# df_scaled_flag0 rows:  7397 / 5289
# The best position is [1960 3587] . The gbest value is [577.69] in iteration number 1
# df_scaled_flag0 rows:  7396 / 5289
# The best position is [4166 1837] . The gbest value is [545.59] in iteration number 2
# df_scaled_flag0 rows:  7395 / 5289
# The best position is [4383 1291] . The gbest value is [681.8] in iteration number 1
# df_scaled_flag0 rows:  7394 / 5289
# The best position is [  46 2112] . The gbest value is [607.38] in iteration number 1
# df_scaled_flag0 rows:  7393 / 5289
# The best position is [2734 6457] . The gbest value is [555.14] in iteration number 1
# df_scaled_flag0 rows:  7392 / 5289
# The best position is [4381 3890] . The gbest value is [590.42] in iteration number 0
# df_scaled_flag0 rows:  7391 / 5289
# The best position is [1113  298] . The gbest value is [581.14] in iteration number 2
# df_scaled_flag0 rows:  7390 / 5289
# The best position is [2306 7132] . The gbest value is [666.4] in iteration number 0
# df_scaled_flag0 rows:  7389 / 5289
# The best position is [ 810 4824] . The gbest value is [505.43] in iteration number 0
# df_scaled_flag0 rows:  7388 / 5289
# The best position is [4357 2027] . The gbest value is [805.52] in iteration number 0
# df_scaled_flag0 rows:  7387 / 5289
# ...
# df_scaled_flag0 rows:  5421 / 5289
# The best position is [2857 5343] . The gbest value is [576.35] in iteration number 0
# df_scaled_flag0 rows:  5420 / 5289
# The best position is [4277 2104] . The gbest value is [516.87] in iteration number 2
# df_scaled_flag0 rows:  5419 / 5289
# The best position is [1875 1036] . The gbest value is [525.64] in iteration number 2
# df_scaled_flag0 rows:  5418 / 5289
# The best position is [5103 3578] . The gbest value is [497.58] in iteration number 0
# df_scaled_flag0 rows:  5417 / 5289
# The best position is [3553 2750] . The gbest value is [493.98] in iteration number 2
# df_scaled_flag0 rows:  5416 / 5289
# The best position is [1059 4400] . The gbest value is [402.78] in iteration number 0
# df_scaled_flag0 rows:  5415 / 5289
# The best position is [360 195] . The gbest value is [622.04] in iteration number 0
# df_scaled_flag0 rows:  5414 / 5289
# The best position is [572 131] . The gbest value is [500.46] in iteration number 0
# df_scaled_flag0 rows:  5413 / 5289
# The best position is [3512 1933] . The gbest value is [446.74] in iteration number 0
# df_scaled_flag0 rows:  5412 / 5289
# The best position is [ 263 5221] . The gbest value is [499.62] in iteration number 0
# df_scaled_flag0 rows:  5411 / 5289
# The best position is [3818  105] . The gbest value is [533.97] in iteration number 0
# df_scaled_flag0 rows:  5410 / 5289
# The best position is [4381 3251] . The gbest value is [526.54] in iteration number 0
# df_scaled_flag0 rows:  5409 / 5289
# The best position is [ 147 5045] . The gbest value is [450.73] in iteration number 0
# df_scaled_flag0 rows:  5408 / 5289
# The best position is [3454 1581] . The gbest value is [628.08] in iteration number 0
# df_scaled_flag0 rows:  5407 / 5289
# The best position is [2678 2949] . The gbest value is [504.6] in iteration number 1
# df_scaled_flag0 rows:  5406 / 5289
# The best position is [1424  799] . The gbest value is [512.91] in iteration number 1
# df_scaled_flag0 rows:  5405 / 5289
# The best position is [1321 2012] . The gbest value is [490.08] in iteration number 2
# df_scaled_flag0 rows:  5404 / 5289
# The best position is [5208 5263] . The gbest value is [528.16] in iteration number 0
# df_scaled_flag0 rows:  5403 / 5289
# The best position is [3331 2062] . The gbest value is [650.56] in iteration number 1
# df_scaled_flag0 rows:  5402 / 5289
# The best position is [4235 3129] . The gbest value is [453.34] in iteration number 1
# df_scaled_flag0 rows:  5401 / 5289
# The best position is [4327 1176] . The gbest value is [498.16] in iteration number 0
# df_scaled_flag0 rows:  5400 / 5289
# The best position is [1635 1509] . The gbest value is [462.59] in iteration number 1
# df_scaled_flag0 rows:  5399 / 5289
# The best position is [1668 2955] . The gbest value is [637.96] in iteration number 0
# df_scaled_flag0 rows:  5398 / 5289
# The best position is [4253  857] . The gbest value is [592.14] in iteration number 1
# df_scaled_flag0 rows:  5397 / 5289
# The best position is [1569 4284] . The gbest value is [501.07] in iteration number 1
# df_scaled_flag0 rows:  5396 / 5289
# The best position is [4491  407] . The gbest value is [568.53] in iteration number 0
# df_scaled_flag0 rows:  5395 / 5289
# The best position is [3455 3917] . The gbest value is [534.12] in iteration number 2
# df_scaled_flag0 rows:  5394 / 5289
# The best position is [1270 3915] . The gbest value is [540.36] in iteration number 1
# df_scaled_flag0 rows:  5393 / 5289
# The best position is [1420 2339] . The gbest value is [574.5] in iteration number 1
# df_scaled_flag0 rows:  5392 / 5289
# The best position is [2838 3120] . The gbest value is [541.2] in iteration number 1
# df_scaled_flag0 rows:  5391 / 5289
# The best position is [4650 1731] . The gbest value is [499.97] in iteration number 0
# df_scaled_flag0 rows:  5390 / 5289
# The best position is [4873 4872] . The gbest value is [578.09] in iteration number 0
# df_scaled_flag0 rows:  5389 / 5289
# The best position is [4699  870] . The gbest value is [501.47] in iteration number 2
# df_scaled_flag0 rows:  5388 / 5289
# The best position is [3841 2639] . The gbest value is [556.32] in iteration number 2
# df_scaled_flag0 rows:  5387 / 5289
# The best position is [4611 2936] . The gbest value is [553.22] in iteration number 1
# df_scaled_flag0 rows:  5386 / 5289
# The best position is [2794 2516] . The gbest value is [576.05] in iteration number 2
# df_scaled_flag0 rows:  5385 / 5289
# The best position is [3314 5229] . The gbest value is [554.35] in iteration number 0
# df_scaled_flag0 rows:  5384 / 5289
# The best position is [2560 4257] . The gbest value is [461.37] in iteration number 1
# df_scaled_flag0 rows:  5383 / 5289
# The best position is [4331  821] . The gbest value is [534.71] in iteration number 1
# df_scaled_flag0 rows:  5382 / 5289
# The best position is [ 627 4887] . The gbest value is [537.41] in iteration number 0
# df_scaled_flag0 rows:  5381 / 5289
# The best position is [5269 2863] . The gbest value is [521.96] in iteration number 0
# df_scaled_flag0 rows:  5380 / 5289
# The best position is [4348 2045] . The gbest value is [459.03] in iteration number 2
# df_scaled_flag0 rows:  5379 / 5289
# The best position is [4623 4855] . The gbest value is [518.38] in iteration number 0
# df_scaled_flag0 rows:  5378 / 5289
# The best position is [ 102 3980] . The gbest value is [552.85] in iteration number 1
# df_scaled_flag0 rows:  5377 / 5289
# The best position is [4115 2013] . The gbest value is [437.58] in iteration number 2
# df_scaled_flag0 rows:  5376 / 5289
# The best position is [  58 4457] . The gbest value is [529.81] in iteration number 0
# df_scaled_flag0 rows:  5375 / 5289
# The best position is [2435  109] . The gbest value is [527.95] in iteration number 0
# df_scaled_flag0 rows:  5374 / 5289
# The best position is [ 763 1737] . The gbest value is [492.14] in iteration number 0
# df_scaled_flag0 rows:  5373 / 5289
# The best position is [3146  726] . The gbest value is [588.01] in iteration number 1
# df_scaled_flag0 rows:  5372 / 5289
# The best position is [1294 5186] . The gbest value is [497.81] in iteration number 1
# df_scaled_flag0 rows:  5371 / 5289
# The best position is [2932 5230] . The gbest value is [492.08] in iteration number 0
# df_scaled_flag0 rows:  5370 / 5289
# The best position is [4839 4335] . The gbest value is [488.52] in iteration number 0
# df_scaled_flag0 rows:  5369 / 5289
# The best position is [4721 3380] . The gbest value is [410.85] in iteration number 1
# df_scaled_flag0 rows:  5368 / 5289
# The best position is [4562  772] . The gbest value is [453.08] in iteration number 2
# df_scaled_flag0 rows:  5367 / 5289
# The best position is [1304 4188] . The gbest value is [458.17] in iteration number 2
# df_scaled_flag0 rows:  5366 / 5289
# The best position is [ 762 4473] . The gbest value is [522.48] in iteration number 1
# df_scaled_flag0 rows:  5365 / 5289
# The best position is [5211 5298] . The gbest value is [554.58] in iteration number 0
# df_scaled_flag0 rows:  5364 / 5289
# The best position is [3825 1266] . The gbest value is [507.38] in iteration number 2
# df_scaled_flag0 rows:  5363 / 5289
# The best position is [1150  881] . The gbest value is [439.56] in iteration number 0
# df_scaled_flag0 rows:  5362 / 5289
# The best position is [2634 3324] . The gbest value is [563.29] in iteration number 1
# df_scaled_flag0 rows:  5361 / 5289
# The best position is [2325 1560] . The gbest value is [674.35] in iteration number 2
# df_scaled_flag0 rows:  5360 / 5289
# The best position is [ 928 5354] . The gbest value is [688.6] in iteration number 0
# df_scaled_flag0 rows:  5359 / 5289
# The best position is [3876 1530] . The gbest value is [466.1] in iteration number 2
# df_scaled_flag0 rows:  5358 / 5289
# The best position is [151 162] . The gbest value is [538.78] in iteration number 0
# df_scaled_flag0 rows:  5357 / 5289
# The best position is [4778 5272] . The gbest value is [645.96] in iteration number 0
# df_scaled_flag0 rows:  5356 / 5289
# The best position is [3769 1094] . The gbest value is [454.09] in iteration number 0
# df_scaled_flag0 rows:  5355 / 5289
# The best position is [361 630] . The gbest value is [478.63] in iteration number 2
# df_scaled_flag0 rows:  5354 / 5289
# The best position is [4530 3636] . The gbest value is [424.45] in iteration number 0
# df_scaled_flag0 rows:  5353 / 5289
# The best position is [3007 1369] . The gbest value is [412.18] in iteration number 0
# df_scaled_flag0 rows:  5352 / 5289
# The best position is [ 516 4160] . The gbest value is [398.41] in iteration number 1
# df_scaled_flag0 rows:  5351 / 5289
# The best position is [924 779] . The gbest value is [459.82] in iteration number 0
# df_scaled_flag0 rows:  5350 / 5289
# The best position is [2576 4370] . The gbest value is [520.66] in iteration number 0
# df_scaled_flag0 rows:  5349 / 5289
# The best position is [ 599 3615] . The gbest value is [475.81] in iteration number 0
# df_scaled_flag0 rows:  5348 / 5289
# The best position is [2514 1934] . The gbest value is [471.28] in iteration number 0
# df_scaled_flag0 rows:  5347 / 5289
# The best position is [ 292 2673] . The gbest value is [555.65] in iteration number 0
# df_scaled_flag0 rows:  5346 / 5289
# The best position is [4574 4779] . The gbest value is [410.74] in iteration number 1
# df_scaled_flag0 rows:  5345 / 5289
# The best position is [ 207 1551] . The gbest value is [571.84] in iteration number 0
# df_scaled_flag0 rows:  5344 / 5289
# The best position is [5281  397] . The gbest value is [524.18] in iteration number 0
# df_scaled_flag0 rows:  5343 / 5289
# The best position is [1691 4427] . The gbest value is [413.92] in iteration number 1
# df_scaled_flag0 rows:  5342 / 5289
# The best position is [3467 3517] . The gbest value is [609.62] in iteration number 0
# df_scaled_flag0 rows:  5341 / 5289
# The best position is [1247  181] . The gbest value is [437.55] in iteration number 0
# df_scaled_flag0 rows:  5340 / 5289
# The best position is [2181 3893] . The gbest value is [457.97] in iteration number 0
# df_scaled_flag0 rows:  5339 / 5289
# The best position is [5011 1629] . The gbest value is [514.18] in iteration number 0
# df_scaled_flag0 rows:  5338 / 5289
# The best position is [4291  556] . The gbest value is [443.07] in iteration number 2
# df_scaled_flag0 rows:  5337 / 5289
# The best position is [5002 1361] . The gbest value is [449.31] in iteration number 2
# df_scaled_flag0 rows:  5336 / 5289
# The best position is [3960 3952] . The gbest value is [432.88] in iteration number 2
# df_scaled_flag0 rows:  5335 / 5289
# The best position is [3928 3587] . The gbest value is [530.23] in iteration number 2
# df_scaled_flag0 rows:  5334 / 5289
# The best position is [3974 3963] . The gbest value is [469.68] in iteration number 0
# df_scaled_flag0 rows:  5333 / 5289
# The best position is [3079 3239] . The gbest value is [551.9] in iteration number 1
# df_scaled_flag0 rows:  5332 / 5289
# The best position is [2878 5239] . The gbest value is [492.2] in iteration number 0
# df_scaled_flag0 rows:  5331 / 5289
# The best position is [3362 3104] . The gbest value is [297.6] in iteration number 0
# df_scaled_flag0 rows:  5330 / 5289
# The best position is [3190 2786] . The gbest value is [485.92] in iteration number 1
# df_scaled_flag0 rows:  5329 / 5289
# The best position is [2804 1592] . The gbest value is [450.27] in iteration number 2
# df_scaled_flag0 rows:  5328 / 5289
# The best position is [2415  870] . The gbest value is [592.96] in iteration number 1
# df_scaled_flag0 rows:  5327 / 5289
# The best position is [1230 5094] . The gbest value is [501.66] in iteration number 0
# df_scaled_flag0 rows:  5326 / 5289
# The best position is [3447 2467] . The gbest value is [450.97] in iteration number 2
# df_scaled_flag0 rows:  5325 / 5289
# The best position is [1289 3346] . The gbest value is [319.29] in iteration number 1
# df_scaled_flag0 rows:  5324 / 5289
# The best position is [608 183] . The gbest value is [486.48] in iteration number 0
# df_scaled_flag0 rows:  5323 / 5289
# The best position is [4488 1587] . The gbest value is [503.] in iteration number 2
# df_scaled_flag0 rows:  5322 / 5289
# The best position is [3477 2471] . The gbest value is [549.92] in iteration number 1
# df_scaled_flag0 rows:  5321 / 5289
# The best position is [4604 4775] . The gbest value is [527.37] in iteration number 0
# df_scaled_flag0 rows:  5320 / 5289
# The best position is [3274 4486] . The gbest value is [392.86] in iteration number 2
# df_scaled_flag0 rows:  5319 / 5289
# The best position is [4470 5277] . The gbest value is [592.15] in iteration number 0
# df_scaled_flag0 rows:  5318 / 5289
# The best position is [3433 4901] . The gbest value is [440.37] in iteration number 0
# df_scaled_flag0 rows:  5317 / 5289
# The best position is [4532  285] . The gbest value is [594.43] in iteration number 0
# df_scaled_flag0 rows:  5316 / 5289
# The best position is [2090 4132] . The gbest value is [435.39] in iteration number 1
# df_scaled_flag0 rows:  5315 / 5289
# The best position is [1577 1640] . The gbest value is [493.94] in iteration number 0
# df_scaled_flag0 rows:  5314 / 5289
# The best position is [1536 4356] . The gbest value is [445.07] in iteration number 2
# df_scaled_flag0 rows:  5313 / 5289
# The best position is [3292  854] . The gbest value is [540.49] in iteration number 1
# df_scaled_flag0 rows:  5312 / 5289
# The best position is [2143  800] . The gbest value is [545.9] in iteration number 1
# df_scaled_flag0 rows:  5311 / 5289
# The best position is [4570  638] . The gbest value is [584.26] in iteration number 0
# df_scaled_flag0 rows:  5310 / 5289
# The best position is [3490  898] . The gbest value is [437.86] in iteration number 2
# df_scaled_flag0 rows:  5309 / 5289
# The best position is [828 177] . The gbest value is [563.17] in iteration number 1
# df_scaled_flag0 rows:  5308 / 5289
# The best position is [4793  276] . The gbest value is [606.] in iteration number 0
# df_scaled_flag0 rows:  5307 / 5289
# The best position is [4794 2205] . The gbest value is [517.87] in iteration number 1
# df_scaled_flag0 rows:  5306 / 5289
# The best position is [4792  774] . The gbest value is [621.15] in iteration number 0
# df_scaled_flag0 rows:  5305 / 5289
# The best position is [3545 1303] . The gbest value is [388.18] in iteration number 1
# df_scaled_flag0 rows:  5304 / 5289
# The best position is [2759 5183] . The gbest value is [567.6] in iteration number 0
# df_scaled_flag0 rows:  5303 / 5289
# The best position is [3311 1424] . The gbest value is [533.59] in iteration number 0
# df_scaled_flag0 rows:  5302 / 5289
# The best position is [2795 3800] . The gbest value is [635.14] in iteration number 2
# df_scaled_flag0 rows:  5301 / 5289
# The best position is [4698 3275] . The gbest value is [465.07] in iteration number 0
# df_scaled_flag0 rows:  5300 / 5289
# The best position is [4481  218] . The gbest value is [482.27] in iteration number 0
# df_scaled_flag0 rows:  5299 / 5289
# The best position is [5094 1826] . The gbest value is [598.8] in iteration number 0
# df_scaled_flag0 rows:  5298 / 5289
# The best position is [3025 2292] . The gbest value is [563.19] in iteration number 1
# df_scaled_flag0 rows:  5297 / 5289
# The best position is [2241 1499] . The gbest value is [381.76] in iteration number 2
# df_scaled_flag0 rows:  5296 / 5289
# The best position is [3959 3761] . The gbest value is [521.78] in iteration number 0
# df_scaled_flag0 rows:  5295 / 5289
# The best position is [1978  935] . The gbest value is [526.23] in iteration number 0
# df_scaled_flag0 rows:  5294 / 5289
# The best position is [4570 4756] . The gbest value is [601.35] in iteration number 0
# df_scaled_flag0 rows:  5293 / 5289
# The best position is [1680  742] . The gbest value is [394.88] in iteration number 1
# df_scaled_flag0 rows:  5292 / 5289
# The best position is [2223 4007] . The gbest value is [378.11] in iteration number 2
# df_scaled_flag0 rows:  5291 / 5289
# The best position is [3744 3072] . The gbest value is [485.9] in iteration number 0
# df_scaled_flag0 rows:  5290 / 5289
# The best position is [1228 1280] . The gbest value is [517.1] in iteration number 0
# df_scaled_flag0 rows:  5289 / 5289
# PSO Iteration Time elapsed (hh:mm:ss.ms) 0:18:39.449036
# 2020-08-03 02:41:35.716753+08:00
# PSO Iteration DONE

# %%
df_scaled_flag0_gbest_final
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  day  month  duration  campaign  pdays  previous  poutcome  New_Class
# 5       17    4        1          2        0     1147        1     0        2    4      8       139         0      0         0         3          0
# 6       10    4        2          2        0     1363        1     1        2    4      8       217         0      0         0         3          0
# 7       24    2        0          2        1      918        1     0        2    4      8       380         0      0         0         3          0
# 10      23    0        0          1        0     1186        1     0        2    4      8       222         0      0         0         3          0
# 11      11    0        2          1        0     1306        1     0        2    4      8       137         0      0         0         3          0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...  ...    ...       ...       ...    ...       ...       ...        ...
# 45167   30    0        1          1        0     1094        0     0        0    9      9       228         0      0         0         3          0
# 45170    1    8        2          0        0     1161        0     0        1    9      9        98         1    107         2         1          0
# 45183   52    5        1          0        0     1240        0     0        0   14      9        78         0     93         7         2          0
# 45189    7    7        2          1        0     1115        0     0        0   15      9       173         0     89         5         0          0
# 45194   41    4        1          2        0     1054        1     1        0   15      9       162         1    184         5         0          0
#
# [5289 rows x 17 columns]

# %%
# Combine this undersampled FLAG0 df with df FLAG1

df_balance_pso = pd.concat([df_scaled_flag0_gbest_final, df_scaled_flag1])
df_balance_pso = df_balance_pso.reset_index()
df_balance_pso = df_balance_pso.iloc[:,1:]
df_balance_pso
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  day  month  duration  campaign  pdays  previous  poutcome  New_Class
# 0       17    4        1          2        0     1147        1     0        2    4      8       139         0      0         0         3          0
# 1       10    4        2          2        0     1363        1     1        2    4      8       217         0      0         0         3          0
# 2       24    2        0          2        1      918        1     0        2    4      8       380         0      0         0         3          0
# 3       23    0        0          1        0     1186        1     0        2    4      8       222         0      0         0         3          0
# 4       11    0        2          1        0     1306        1     0        2    4      8       137         0      0         0         3          0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...  ...    ...       ...       ...    ...       ...       ...        ...
# 10573   55    5        1          1        0     3678        0     0        0   16      9       300         0     37         8         0          1
# 10574    7    9        2          1        0     1421        0     1        0   16      9       386         1      0         0         3          1
# 10575   33    9        1          2        0     1741        0     0        0   16      9       975         2      0         0         3          1
# 10576   53    5        0          0        0     2639        0     0        0   16      9       456         1      0         0         3          1
# 10577   54    5        1          1        0     5455        0     0        0   16      9      1116         4    181         3         2          1
#
# [10578 rows x 17 columns]

# %%
# Separating the dependent and independent variables 

X_pso = df_balance_pso.drop('New_Class', axis = 1) 
y_pso = df_balance_pso['New_Class'] 

X_pso = pd.DataFrame(X_pso)
y_pso = pd.Series(y_pso)

# Separating train, validation and test set
X_train, X_test, y_train, y_test = train_test_split(X_pso, y_pso, test_size=test_size, random_state=2)

# %%
# Plotting the sets

plot_height = (len(df_balance_pso[df_balance_pso.New_Class == 0]) * 0.8) + 10

fig, ax = plt.subplots(1, 2, figsize=(30, 10))
plt.subplot(1, 2, 1)
colors = ["green", "red"]
df_train = pd.DataFrame(y_train.value_counts())
ax = sns.countplot(y_train, data=df_train, palette=colors)
ax.set_ylim(0, plot_height)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
plt.xlabel('Class', fontweight='bold', fontsize=15)
plt.ylabel('Count', fontweight='bold', fontsize=15)
plt.title('TRAIN SET: Class Distributions (0/Negative/No || 1/Positive/Yes)', fontweight='bold', fontsize=15)

plt.subplot(1, 2, 2)
colors = ["green", "red"]
df_train = pd.DataFrame(y_test.value_counts())
ax = sns.countplot(y_test, data=df_train, palette=colors)
ax.set_ylim(0, plot_height)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
plt.xlabel('Class', fontweight='bold', fontsize=15)
plt.ylabel('Count', fontweight='bold', fontsize=15)
plt.title('TEST SET: Class Distributions (0/Negative/No || 1/Positive/Yes)', fontweight='bold', fontsize=15)

print("After", program_name, ":")
print("X_train:")
print('Negative', round(y_train.value_counts()[0]/len(y_train) * 100,2), '% of the dataset:', y_train.value_counts()[0])
print('Positive', round(y_train.value_counts()[1]/len(y_train) * 100,2), '% of the dataset:', y_train.value_counts()[1])
print("")
print("X_test:")
print('Negative', round(y_test.value_counts()[0]/len(y_test) * 100,2), '% of the dataset:', y_test.value_counts()[0])
print('Positive', round(y_test.value_counts()[1]/len(y_test) * 100,2), '% of the dataset:', y_test.value_counts()[1])
print("")

plt.show()
# Out:
# After PSO :
# X_train:
# Negative 50.2 % of the dataset: 4248
# Positive 49.8 % of the dataset: 4214
#
# X_test:
# Negative 49.2 % of the dataset: 1041
# Positive 50.8 % of the dataset: 1075

# %%
# Classification with PSO Balanced Dataset

classifiers = [MLPClassifier(), SVC(probability=True), XGBClassifier(), RandomForestClassifier(), LogisticRegression(max_iter=5000)]
balanced_result_table_test = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])
balanced_result_table_test_f1 = pd.DataFrame(columns=['Classifiers', 'Accuracy','Sensitivity', 'Specificity', 'Precision', 'F1Score', 'AUC', 'AveragePrecisionRecall'])

for cls in classifiers:
    model = cls.fit(X_train, y_train)

    # TEST set
    yproba = model.predict_proba(X_test)[::,1]
    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)
    balanced_result_table_test = balanced_result_table_test.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)
    
    print("=====================================================================")
    print("Classifier = ", cls)
    print("TEST SET")
    y_pred = cls.predict(X_test)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    accuracy = accuracy_score(y_test, y_pred)
    f1score = f1_score(y_test, y_pred, pos_label=1, average='macro')
    average_precision = average_precision_score(y_test, y_pred, average='weighted')
    ##print("Accuracy : ", accuracy)
    ##print("F1 Score : ", f1score)
    ##print("AUC : ", auc)
    ##print("Average Precision Recall: ", average_precision)
    print("")
    report = classification_report(y_test, y_pred, output_dict=True)
    df_report = pd.DataFrame(report).transpose()
    
    
    precision, recall, fscore, support = score(y_test, y_pred)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    specificity = tn / (tn+fp)
    recall = np.round(recall, 4)
    precision = np.round(precision, 4)
    fscore = np.round(fscore, 4)
    ##print('Accuracy: {}'.format(np.round(accuracy * 100, 2)))
    ##print('Sensitivity: {}'.format(np.round(recall * 100, 2)))
    ##print('Specificity: {}'.format(np.round(specificity * 100, 2)))
    ##print('Precision: {}'.format(np.round(precision * 100, 2)))
    ##print('F1Score: {}'.format(np.round(fscore * 100, 2)))
    balanced_result_table_test_f1 = balanced_result_table_test_f1.append({'Classifiers':str(cls)[0:3],
                                        'Accuracy':accuracy, 
                                        'Sensitivity':recall, 
                                        'Specificity':specificity, 
                                        'Precision':precision, 
                                        'F1Score':fscore,
                                        'AUC':auc, 
                                        'AveragePrecisionRecall':average_precision}, ignore_index=True)
    
# Set name of the classifiers as index labels
pd.options.display.max_columns = None
pd.set_option('display.expand_frame_repr', False)
balanced_result_table_test.set_index('classifiers', inplace=True)
# Out:
# =====================================================================
# Classifier =  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# TEST SET
# [[969  72]
#  [167 908]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      1041
#            1       0.93      0.84      0.88      1075
#
#     accuracy                           0.89      2116
#    macro avg       0.89      0.89      0.89      2116
# weighted avg       0.89      0.89      0.89      2116
#
#
# =====================================================================
# Classifier =  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)
# TEST SET
# [[1015   26]
#  [ 226  849]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1041
#            1       0.97      0.79      0.87      1075
#
#     accuracy                           0.88      2116
#    macro avg       0.89      0.88      0.88      2116
# weighted avg       0.90      0.88      0.88      2116
#
#
# =====================================================================
# Classifier =  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)
# TEST SET
# [[994  47]
#  [106 969]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93      1041
#            1       0.95      0.90      0.93      1075
#
#     accuracy                           0.93      2116
#    macro avg       0.93      0.93      0.93      2116
# weighted avg       0.93      0.93      0.93      2116
#
#
# =====================================================================
# Classifier =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# TEST SET
# [[980  61]
#  [ 84 991]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1041
#            1       0.94      0.92      0.93      1075
#
#     accuracy                           0.93      2116
#    macro avg       0.93      0.93      0.93      2116
# weighted avg       0.93      0.93      0.93      2116
#
#
# =====================================================================
# Classifier =  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=5000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# TEST SET
# [[948  93]
#  [145 930]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      1041
#            1       0.91      0.87      0.89      1075
#
#     accuracy                           0.89      2116
#    macro avg       0.89      0.89      0.89      2116
# weighted avg       0.89      0.89      0.89      2116

# %%
# Results performance bar plot (PSO Balanced Dataset)

color = ('#FF4136', '#2ECC40', '#FF851B', '#0074D9')
#FF851B orange, #FF4136 red, #0074D9, blue, #2ECC40 green)

# Function plotting the results performance
def plot_result(result_table, result_set, dataset):
  result_table = result_table.set_index('Classifiers')
  result_table = result_table.round(4)
  print(program_name, result_set, 'set result:\n', result_table)
  #ax = result_table.plot.bar(color=color, figsize=(20, 9))
  #plt.xticks(rotation=0)
  #plt.ylabel("Performance", fontsize=15)
  #plt.xlabel("Classifiers", fontsize=15)
  #plt.ylim(0, 1.03)
  #plt.grid(True)
  #plt.legend(loc=2)
  #plt.title('{} Dataset - {} Set ({}) performance'.format(dataset, result_set, dataset_set), fontweight='bold', fontsize=15)
  
  i = 0
  label = np.round(result_table.Accuracy.values, 2)
  for p in ax.patches:
      ax.annotate(str(round(p.get_height(),2 )), (p.get_x() * 1.005, p.get_height() * 1.005), fontweight='bold', fontsize=12)
      i = i+1

  plt.show()            
  print("")

plot_result(balanced_result_table_test_f1, "Test", "PSO Balanced")
# Out:
# PSO Test set result:
#               Accuracy       Sensitivity  Specificity         Precision           F1Score     AUC  AveragePrecisionRecall
# Classifiers
# MLP            0.8871  [0.9308, 0.8447]       0.9308   [0.853, 0.9265]  [0.8902, 0.8837]  0.9579                  0.8615
# SVC            0.8809   [0.975, 0.7898]       0.9750  [0.8179, 0.9703]  [0.8896, 0.8708]  0.9515                  0.8731
# XGB            0.9277  [0.9549, 0.9014]       0.9549  [0.9036, 0.9537]  [0.9285, 0.9268]  0.9832                  0.9098
# Ran            0.9315  [0.9414, 0.9219]       0.9414   [0.9211, 0.942]  [0.9311, 0.9318]  0.9845                  0.9081
# Log            0.8875  [0.9107, 0.8651]       0.9107  [0.8673, 0.9091]  [0.8885, 0.8866]  0.9532                  0.8550

# %%
# # Plotting ROC/AUC

# # Function plotting AUC
# def plot_roc(result_table, result_set, dataset):
#   fig1 = plt.figure(1, figsize=(16,8))
#   for i in result_table.index:
#     plt.plot(result_table.loc[i]['fpr'], 
#              result_table.loc[i]['tpr'], 
#              label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
#   plt.plot([0,1], [0,1], color='orange', linestyle='--')
#   plt.xticks(np.arange(0.0, 1.1, step=0.1))
#   plt.xlabel("False Positive Rate", fontsize=15)
#   plt.yticks(np.arange(0.0, 1.1, step=0.1))
#   plt.ylabel("True Positive Rate", fontsize=15)
#   plt.title('{} Dataset - {} Set: ROC Chart'.format(dataset, result_set), fontweight='bold', fontsize=15)
#   plt.legend(prop={'size':13}, loc='lower right')

#   plt.show()
#   #fig.savefig('multiple_roc_curve.png')

# plot_roc(balanced_result_table_test, "Test", "PSO Balanced")

# %% [markdown]
# # Random Undersampling (RUS)

# %%
# RUS then Separating train and test set

from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import NearMiss
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import OneSidedSelection
from imblearn.under_sampling import NeighbourhoodCleaningRule
from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import AllKNN
from collections import Counter

rus = RandomUnderSampler(random_state=47)
#rus = NearMiss(version=1, n_neighbors=3) # NearMiss(version=2, n_neighbors=3)
#rus = CondensedNearestNeighbour(n_neighbors=1)
#rus = TomekLinks()
#rus = EditedNearestNeighbours(n_neighbors=3)
#rus = OneSidedSelection(n_neighbors=1, n_seeds_S=200)
#rus = NeighbourhoodCleaningRule(n_neighbors=3, threshold_cleaning=0.5)
#rus = ClusterCentroids(random_state=0)
#rus = AllKNN()

X = df.drop('New_Class', axis = 1) 
y = df['New_Class'] 

# RUS
start_time = datetime.now() 
X_rus, y_rus = rus.fit_resample(X, y)
print("")
print('Resampled dataset shape %s' % Counter(y_rus))

print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))

X_rus = pd.DataFrame(X_rus)
y_rus = pd.Series(y_rus)

X_train, X_test, y_train, y_test = train_test_split(X_rus, y_rus, test_size=0.2, random_state=3)
# Out:
# Resampled dataset shape Counter({0: 5289, 1: 5289})
# Time elapsed (hh:mm:ss.ms) 0:00:00.018384
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Plotting the sets

plot_height = (len(df_balance_pso[df_balance_pso.New_Class == 0]) * 0.8) + 10

fig, ax = plt.subplots(1, 2, figsize=(30, 10))
plt.subplot(1, 2, 1)
colors = ["green", "red"]
df_train = pd.DataFrame(y_train.value_counts())
ax = sns.countplot(y_train, data=df_train, palette=colors)
ax.set_ylim(0, plot_height)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
plt.xlabel('Class', fontweight='bold', fontsize=15)
plt.ylabel('Count', fontweight='bold', fontsize=15)
plt.title('TRAIN SET: Class Distributions (0/Negative/No || 1/Positive/Yes)', fontweight='bold', fontsize=15)

plt.subplot(1, 2, 2)
colors = ["green", "red"]
df_train = pd.DataFrame(y_test.value_counts())
ax = sns.countplot(y_test, data=df_train, palette=colors)
ax.set_ylim(0, plot_height)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
plt.xlabel('Class', fontweight='bold', fontsize=15)
plt.ylabel('Count', fontweight='bold', fontsize=15)
plt.title('TEST SET: Class Distributions (0/Negative/No || 1/Positive/Yes)', fontweight='bold', fontsize=15)

print("After RUS:")
print("X_train:")
print('Negative', round(y_train.value_counts()[0]/len(y_train) * 100,2), '% of the dataset:', y_train.value_counts()[0])
print('Positive', round(y_train.value_counts()[1]/len(y_train) * 100,2), '% of the dataset:', y_train.value_counts()[1])
print("")
print("X_test:")
print('Negative', round(y_test.value_counts()[0]/len(y_test) * 100,2), '% of the dataset:', y_test.value_counts()[0])
print('Positive', round(y_test.value_counts()[1]/len(y_test) * 100,2), '% of the dataset:', y_test.value_counts()[1])
print("")

plt.show()
# Out:
# After RUS:
# X_train:
# Negative 49.95 % of the dataset: 4227
# Positive 50.05 % of the dataset: 4235
#
# X_test:
# Negative 50.19 % of the dataset: 1062
# Positive 49.81 % of the dataset: 1054

# %%
# Classification with RUS Balanced Dataset

classifiers = [MLPClassifier(), SVC(probability=True), XGBClassifier(), RandomForestClassifier(), LogisticRegression(max_iter=5000)]
rus_result_table_test = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])
rus_result_table_test_f1 = pd.DataFrame(columns=['Classifiers', 'Accuracy','Sensitivity', 'Specificity', 'Precision', 'F1Score', 'AUC', 'AveragePrecisionRecall'])

for cls in classifiers:
    model = cls.fit(X_train, y_train)

    # TEST set
    yproba = model.predict_proba(X_test)[::,1]
    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)
    rus_result_table_test = rus_result_table_test.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)
    
    print("=====================================================================")
    print("Classifier = ", cls)
    print("TEST SET")
    y_pred = cls.predict(X_test)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    accuracy = accuracy_score(y_test, y_pred)
    f1score = f1_score(y_test, y_pred, pos_label=1, average='macro')
    average_precision = average_precision_score(y_test, y_pred, average='weighted')
    ##print("Accuracy : ", accuracy)
    ##print("F1 Score : ", f1score)
    ##print("AUC : ", auc)
    ##print("Average Precision Recall: ", average_precision)
    print("")
    report = classification_report(y_test, y_pred, output_dict=True)
    df_report = pd.DataFrame(report).transpose()
    
    
    precision, recall, fscore, support = score(y_test, y_pred)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    specificity = tn / (tn+fp)
    recall = np.round(recall, 4)
    precision = np.round(precision, 4)
    fscore = np.round(fscore, 4)
    ##print('Accuracy: {}'.format(np.round(accuracy * 100, 2)))
    ##print('Sensitivity: {}'.format(np.round(recall * 100, 2)))
    ##print('Specificity: {}'.format(np.round(specificity * 100, 2)))
    ##print('Precision: {}'.format(np.round(precision * 100, 2)))
    ##print('F1Score: {}'.format(np.round(fscore * 100, 2)))
    rus_result_table_test_f1 = rus_result_table_test_f1.append({'Classifiers':str(cls)[0:3],
                                        'Accuracy':accuracy, 
                                        'Sensitivity':recall, 
                                        'Specificity':specificity, 
                                        'Precision':precision, 
                                        'F1Score':fscore,
                                        'AUC':auc, 
                                        'AveragePrecisionRecall':average_precision}, ignore_index=True)
    
# Set name of the classifiers as index labels
pd.options.display.max_columns = None
pd.set_option('display.expand_frame_repr', False)
rus_result_table_test.set_index('classifiers', inplace=True)
# Out:
# =====================================================================
# Classifier =  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# TEST SET
# [[900 162]
#  [363 691]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77      1062
#            1       0.81      0.66      0.72      1054
#
#     accuracy                           0.75      2116
#    macro avg       0.76      0.75      0.75      2116
# weighted avg       0.76      0.75      0.75      2116
#
#
# =====================================================================
# Classifier =  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)
# TEST SET
# [[832 230]
#  [309 745]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76      1062
#            1       0.76      0.71      0.73      1054
#
#     accuracy                           0.75      2116
#    macro avg       0.75      0.75      0.74      2116
# weighted avg       0.75      0.75      0.74      2116
#
#
# =====================================================================
# Classifier =  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)
# TEST SET
# [[877 185]
#  [147 907]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      1062
#            1       0.83      0.86      0.85      1054
#
#     accuracy                           0.84      2116
#    macro avg       0.84      0.84      0.84      2116
# weighted avg       0.84      0.84      0.84      2116
#
#
# =====================================================================
# Classifier =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# TEST SET
# [[879 183]
#  [145 909]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      1062
#            1       0.83      0.86      0.85      1054
#
#     accuracy                           0.84      2116
#    macro avg       0.85      0.85      0.84      2116
# weighted avg       0.85      0.84      0.84      2116
#
#
# =====================================================================
# Classifier =  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=5000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# TEST SET
# [[869 193]
#  [215 839]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      1062
#            1       0.81      0.80      0.80      1054
#
#     accuracy                           0.81      2116
#    macro avg       0.81      0.81      0.81      2116
# weighted avg       0.81      0.81      0.81      2116

# %%
# Results performance bar plot (RUS Balanced Dataset)

color = ('#FF4136', '#2ECC40', '#FF851B', '#0074D9')
#FF851B orange, #FF4136 red, #0074D9, blue, #2ECC40 green)

# Function plotting the results performance
def plot_result(result_table, result_set, dataset):
  result_table = result_table.set_index('Classifiers')
  result_table = result_table.round(4)
  print("RUS", result_set, 'set result:\n', result_table)
  #ax = result_table.plot.bar(color=color, figsize=(20, 9))
  #plt.xticks(rotation=0)
  #plt.ylabel("Performance", fontsize=15)
  #plt.xlabel("Classifiers", fontsize=15)
  #plt.ylim(0, 1.03)
  #plt.grid(True)
  #plt.legend(loc=2)
  #plt.title('{} Dataset - {} Set ({}) performance'.format(dataset, result_set, dataset_set), fontweight='bold', fontsize=15)
  
  i = 0
  label = np.round(result_table.Accuracy.values, 2)
  for p in ax.patches:
      ax.annotate(str(round(p.get_height(),2 )), (p.get_x() * 1.005, p.get_height() * 1.005), fontweight='bold', fontsize=12)
      i = i+1

  plt.show()            
  print("")

plot_result(rus_result_table_test_f1, "Test", "RUS Balanced")
# Out:
# RUS Test set result:
#               Accuracy       Sensitivity  Specificity         Precision           F1Score     AUC  AveragePrecisionRecall
# Classifiers
# MLP            0.7519  [0.8475, 0.6556]       0.8475  [0.7126, 0.8101]  [0.7742, 0.7247]  0.8482                  0.7026
# SVC            0.7453  [0.7834, 0.7068]       0.7834  [0.7292, 0.7641]  [0.7553, 0.7344]  0.8297                  0.6861
# XGB            0.8431  [0.8258, 0.8605]       0.8258  [0.8564, 0.8306]  [0.8408, 0.8453]  0.9175                  0.7842
# Ran            0.8450  [0.8277, 0.8624]       0.8277  [0.8584, 0.8324]  [0.8428, 0.8472]  0.9150                  0.7864
# Log            0.8072   [0.8183, 0.796]       0.8183   [0.8017, 0.813]  [0.8099, 0.8044]  0.8763                  0.7488

# %%
# # Plotting ROC/AUC

# # Function plotting AUC
# def plot_roc(result_table, result_set, dataset):
#   fig1 = plt.figure(1, figsize=(16,8))
#   for i in result_table.index:
#     plt.plot(result_table.loc[i]['fpr'], 
#              result_table.loc[i]['tpr'], 
#              label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
#   plt.plot([0,1], [0,1], color='orange', linestyle='--')
#   plt.xticks(np.arange(0.0, 1.1, step=0.1))
#   plt.xlabel("False Positive Rate", fontsize=15)
#   plt.yticks(np.arange(0.0, 1.1, step=0.1))
#   plt.ylabel("True Positive Rate", fontsize=15)
#   plt.title('{} Dataset - {} Set: ROC Chart'.format(dataset, result_set), fontweight='bold', fontsize=15)
#   plt.legend(prop={'size':13}, loc='lower right')

#   plt.show()
#   #fig.savefig('multiple_roc_curve.png')

# plot_roc(rus_result_table_test, "Test", "RUS Balanced")

# %% [markdown]
# # Imbalanced vs PSO vs RUS

# %%
# Results performance bar plot (Imbalanced vs PSO vs RUS)

color = ('#FF4136', '#2ECC40', '#FF851B', '#0074D9')
#FF851B orange, #FF4136 red, #0074D9, blue, #2ECC40 green)

# Function plotting the results performance
def plot_result_compare(result_table, result_set, dataset):
  result_table = result_table.set_index('Classifiers')
  #print(program_name, result_set, 'set result:\n', result_table)
  ax = result_table.plot.bar(color=color, figsize=(15, 7))
  plt.xticks(rotation=0)
  plt.ylabel("Performance", fontsize=15)
  plt.xlabel("Classifiers", fontsize=15)
  plt.ylim(0, 1.03)
  plt.grid(True)
  plt.legend(loc=2)
  plt.title('{} Dataset - {} Set ({}) performance'.format(dataset, result_set, dataset_set), fontweight='bold', fontsize=15)
  
  i = 0
  label = np.round(result_table.Accuracy.values, 2)
  for p in ax.patches:
      ax.annotate(str(round(p.get_height(),2 )), (p.get_x() * 1.005, p.get_height() * 1.005), fontweight='bold', fontsize=12)
      i = i+1

  plt.show()            
  print("")

# %%
# Bar Chart Comparison (Imbalanced vs PSO vs RUS)

plot_result_compare(imbalanced_result_table_test_f1, "Test", "Imbalanced")
plot_result_compare(balanced_result_table_test_f1, "Test", "PSO Balanced")
plot_result_compare(rus_result_table_test_f1, "Test", "RUS Balanced")

# %%
# Plotting ROC/AUC

# Function plotting AUC
def plot_roc_compare(result_table, result_set, dataset):
  fig1 = plt.figure(1, figsize=(15, 7))
  for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
  plt.plot([0,1], [0,1], color='orange', linestyle='--')
  plt.xticks(np.arange(0.0, 1.1, step=0.1))
  plt.xlabel("False Positive Rate", fontsize=15)
  plt.yticks(np.arange(0.0, 1.1, step=0.1))
  plt.ylabel("True Positive Rate", fontsize=15)
  plt.title('{} Dataset - {} Set: ROC Chart'.format(dataset, result_set), fontweight='bold', fontsize=15)
  plt.legend(prop={'size':13}, loc='lower right')

  plt.show()
  #fig.savefig('multiple_roc_curve.png')

# %%
# ROC Comparison (Imbalanced vs PSO vs RUS)

plot_roc_compare(imbalanced_result_table_test, "Test", "Imbalanced")
plot_roc_compare(balanced_result_table_test, "Test", "PSO Balanced")
plot_roc_compare(rus_result_table_test, "Test", "RUS Balanced")

# %%
print('TOTAL elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - first_start_time))
print(mytime)
print("ALL DONE")
# Out:
# TOTAL elapsed (hh:mm:ss.ms) 0:23:40.952756
# 2020-08-03 02:41:35.716753+08:00
# ALL DONE
